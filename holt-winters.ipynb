# %% [markdown]
# <a href="https://colab.research.google.com/github/hyeonwoongson/hackathon/blob/main/holt-winters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 훈련 데이터를 새로운 데이터 프레임으로 변환

# %%
import pandas as pd
import re

from google.colab import drive
import pandas as pd

# 1. Google Drive 마운트
drive.mount('/content/drive')

# 2. 파일 경로 지정 및 데이터 불러오기
#    - 파일에 헤더가 있는 경우 names 파라미터는 사용하지 않습니다.
file_path = '/content/drive/MyDrive/hackathon_data/train.csv'
df = pd.read_csv(file_path)

# Inspect the data
print(df.head())
print(df.info())

# Ensure column names are correct
df.columns = ['영업일자', '영업장명_메뉴명', '매출수량']

# Convert '영업일자' to datetime objects
df['영업일자'] = pd.to_datetime(df['영업일자'])

# Extract 'year', 'month', 'day'
df['year'] = df['영업일자'].dt.year
df['month'] = df['영업일자'].dt.month
df['day'] = df['영업일자'].dt.day

# Create 'yoil' (day of week) column
day_of_week_map = {
    'Monday': '월요일',
    'Tuesday': '화요일',
    'Wednesday': '수요일',
    'Thursday': '목요일',
    'Friday': '금요일',
    'Saturday': '토요일',
    'Sunday': '일요일'
}
df['yoil'] = df['영업일자'].dt.day_name().map(day_of_week_map)

# Split '영업장명_메뉴명' into 'restaurant' and 'menu'
df[['restaurant', 'menu']] = df['영업장명_메뉴명'].str.split('_', n=1, expand=True)

# Rename '매출수량' to 'sum'
df = df.rename(columns={'매출수량': 'sum'})

# Create the new DataFrame with the required columns
new_df = df[['year', 'month', 'day', 'yoil', 'restaurant', 'menu', 'sum']]

# Display the new DataFrame's head
print(new_df.head())

# Save the new DataFrame to a CSV file
new_df.to_csv('processed_data.csv', index=False, encoding='utf-8-sig')

print('New DataFrame saved to processed_data.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          영업일자            영업장명_메뉴명  매출수량
# 0  2023-01-01  느티나무 셀프BBQ_1인 수저세트     0
# 1  2023-01-02  느티나무 셀프BBQ_1인 수저세트     0
# 2  2023-01-03  느티나무 셀프BBQ_1인 수저세트     0
# 3  2023-01-04  느티나무 셀프BBQ_1인 수저세트     0
# 4  2023-01-05  느티나무 셀프BBQ_1인 수저세트     0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102676 entries, 0 to 102675
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   영업일자      102676 non-null  object
#  1   영업장명_메뉴명  102676 non-null  object
#  2   매출수량      102676 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.4+ MB
# None
#    year  month  day yoil  restaurant     menu  sum
# 0  2023      1    1  일요일  느티나무 셀프BBQ  1인 수저세트    0
# 1  2023      1    2  월요일  느티나무 셀프BBQ  1인 수저세트    0
# 2  2023      1    3  화요일  느티나무 셀프BBQ  1인 수저세트    0
# 3  2023      1    4  수요일  느티나무 셀프BBQ  1인 수저세트    0
# 4  2023      1    5  목요일  느티나무 셀프BBQ  1인 수저세트    0
# New DataFrame saved to processed_data.csv

# %% [markdown]
# 테스트 데이터 하나의 파일로 모으기

# %%
import pandas as pd
import glob
import os

# Get a list of all TEST_xx.csv files.
# 파일 경로가 올바른지 다시 한번 확인해주세요.
file_list = sorted(glob.glob('/content/drive/MyDrive/hackathon_data/TEST_*.csv'))

if not file_list:
    print("경로에 TEST_*.csv 파일이 없습니다. 경로를 다시 확인해주세요.")
else:
    # Create an empty list to store dataframes.
    df_list = []

    # Read each csv file and append to the list.
    for file in file_list:
        try:
            # 인코딩 오류 방지를 위해 utf-8로 지정합니다.
            df_list.append(pd.read_csv(file, encoding='utf-8'))
        except UnicodeDecodeError:
            print(f"파일 {file}을 utf-8로 디코딩할 수 없습니다. 다른 인코딩을 시도합니다.")
            df_list.append(pd.read_csv(file, encoding='cp949'))

    # Concatenate all dataframes into a single one.
    df_combined = pd.concat(df_list, ignore_index=True)

    # Define a dictionary to map English day names to Korean day names.
    yoil_map = {
        'Monday': '월요일',
        'Tuesday': '화요일',
        'Wednesday': '수요일',
        'Thursday': '목요일',
        'Friday': '금요일',
        'Saturday': '토요일',
        'Sunday': '일요일'
    }

    # Convert '영업일자' to datetime, 유효하지 않은 날짜는 NaT로 변환합니다.
    df_combined['영업일자'] = pd.to_datetime(df_combined['영업일자'], errors='coerce')

    # Extract 'year', 'month', 'day', 'yoil'.
    df_combined['year'] = df_combined['영업일자'].dt.year
    df_combined['month'] = df_combined['영업일자'].dt.month
    df_combined['day'] = df_combined['영업일자'].dt.day
    df_combined['yoil'] = df_combined['영업일자'].dt.day_name().map(yoil_map)

    # Split '영업장명_메뉴명' into 'restaurant' and 'menu'.
    df_combined[['restaurant', 'menu']] = df_combined['영업장명_메뉴명'].str.split('_', expand=True)

    # Rename '매출수량' to 'sum'.
    df_combined = df_combined.rename(columns={'매출수량': 'sum'})

    # Create a new DataFrame with the required columns.
    df_new = df_combined[['year', 'month', 'day', 'yoil', 'restaurant', 'menu', 'sum']]

    # df_new의 정보 확인 (진단용)
    print("--- df_new의 정보 확인 ---")
    df_new.info()

    # df_new의 처음 5개 행 미리보기 (진단용)
    print("\n--- df_new의 처음 5개 행 미리보기 ---")
    print(df_new.head().to_markdown(index=False, numalign="left", stralign="left"))

    # Save the new DataFrame to a CSV file.
    # 인코딩을 'utf-8-sig'로 지정하여 엑셀 호환성을 높입니다.
    df_new.to_csv('transformed_test_data.csv', index=False, encoding='utf-8-sig')
    print("\n'transformed_test_data.csv' 파일이 성공적으로 저장되었습니다.")
# Out:
# --- df_new의 정보 확인 ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54040 entries, 0 to 54039
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        54040 non-null  int32
#  1   month       54040 non-null  int32
#  2   day         54040 non-null  int32
#  3   yoil        54040 non-null  object
#  4   restaurant  54040 non-null  object
#  5   menu        54040 non-null  object
#  6   sum         54040 non-null  int64
# dtypes: int32(3), int64(1), object(3)
# memory usage: 2.3+ MB
#
# --- df_new의 처음 5개 행 미리보기 ---
# | year   | month   | day   | yoil   | restaurant       | menu         | sum   |
# |:-------|:--------|:------|:-------|:-----------------|:-------------|:------|
# | 2024   | 6       | 16    | 일요일 | 느티나무 셀프BBQ | 1인 수저세트 | 2     |
# | 2024   | 6       | 17    | 월요일 | 느티나무 셀프BBQ | 1인 수저세트 | 0     |
# | 2024   | 6       | 18    | 화요일 | 느티나무 셀프BBQ | 1인 수저세트 | 0     |
# | 2024   | 6       | 19    | 수요일 | 느티나무 셀프BBQ | 1인 수저세트 | 0     |
# | 2024   | 6       | 20    | 목요일 | 느티나무 셀프BBQ | 1인 수저세트 | 4     |
#
# 'transformed_test_data.csv' 파일이 성공적으로 저장되었습니다.

# %% [markdown]
# 훈련 데이터 경로 지정

# %%
import os
import shutil
from google.colab import drive

# 1. 구글 드라이브 마운트
print("구글 드라이브를 마운트합니다...")
drive.mount('/content/drive')

# 2. 파일 경로 지정 (원본 파일명과 목표 파일명)
source_file = 'processed_data.csv'
destination_dir = '/content/drive/MyDrive/hackathon_data/'
destination_file = 'processed_data.csv'

# 3. 목표 폴더가 없으면 생성
if not os.path.exists(destination_dir):
    print(f"'{destination_dir}' 폴더를 생성합니다.")
    os.makedirs(destination_dir)

# 4. 파일 이동 및 이름 변경
source_path = os.path.join(os.getcwd(), source_file)
destination_path = os.path.join(destination_dir, destination_file)

try:
    shutil.move(source_path, destination_path)
    print(f"'{source_file}' 파일이 '{destination_path}' 로 성공적으로 이동되었습니다.")
except FileNotFoundError:
    print(f"오류: '{source_file}' 파일을 찾을 수 없습니다. 현재 폴더에 파일이 있는지 확인해 주세요.")

print("\n파일 이동 작업이 완료되었습니다.")
# Out:
# 구글 드라이브를 마운트합니다...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 'processed_data.csv' 파일이 '/content/drive/MyDrive/hackathon_data/processed_data.csv' 로 성공적으로 이동되었습니다.
#
# 파일 이동 작업이 완료되었습니다.

# %% [markdown]
# 훈련 데이터 영업장 기준으로 나누기

# %%
import pandas as pd
import re

# 이전 단계에서 합쳐진 데이터프레임 다시 생성
df1 = pd.read_csv('/content/drive/MyDrive/hackathon_data/processed_data.csv')

# 'restaurant' 열의 고유한 값 확인
restaurants = df1['restaurant'].unique()

# 각 레스토랑별로 데이터프레임을 분리하고 파일로 저장
for restaurant in restaurants:
    # 파일 이름에 사용할 수 있도록 특수문자나 공백을 '_'로 대체
    # 파일명에 사용할 수 없는 문자 (\ / : * ? " < > |)를 제거합니다.
    safe_name = re.sub(r'[\\/:*?"<>|]', '', restaurant).replace(' ', '_')

    # 해당 레스토랑의 데이터만 필터링
    restaurant_df = df1[df1['restaurant'] == restaurant].copy()

    # 새로운 파일 이름 생성
    filename = f"{safe_name}_data.csv"

    # CSV 파일로 저장 (인덱스 제외)
    # 한글 깨짐 방지를 위해 'utf-8-sig' 인코딩을 사용합니다.
    restaurant_df.to_csv(filename, index=False, encoding='utf-8-sig')

    print(f"'{restaurant}' 데이터를 '{filename}' 파일로 저장했습니다.")

print("\n모든 레스토랑 데이터가 개별 파일로 성공적으로 분리되었습니다.")
# Out:
# '느티나무 셀프BBQ' 데이터를 '느티나무_셀프BBQ_data.csv' 파일로 저장했습니다.
# '담하' 데이터를 '담하_data.csv' 파일로 저장했습니다.
# '라그로타' 데이터를 '라그로타_data.csv' 파일로 저장했습니다.
# '미라시아' 데이터를 '미라시아_data.csv' 파일로 저장했습니다.
# '연회장' 데이터를 '연회장_data.csv' 파일로 저장했습니다.
# '카페테리아' 데이터를 '카페테리아_data.csv' 파일로 저장했습니다.
# '포레스트릿' 데이터를 '포레스트릿_data.csv' 파일로 저장했습니다.
# '화담숲주막' 데이터를 '화담숲주막_data.csv' 파일로 저장했습니다.
# '화담숲카페' 데이터를 '화담숲카페_data.csv' 파일로 저장했습니다.
#
# 모든 레스토랑 데이터가 개별 파일로 성공적으로 분리되었습니다.

# %%
import os
import shutil
from google.colab import drive

# 1. 구글 드라이브 마운트
print("구글 드라이브를 마운트합니다...")
drive.mount('/content/drive')

# 2. 파일 경로 지정 (원본 파일명과 목표 파일명)
source_file = 'transformed_test_data.csv'
destination_dir = '/content/drive/MyDrive/hackathon_data/'
destination_file = 'transformed_test_data.csv'

# 3. 목표 폴더가 없으면 생성
if not os.path.exists(destination_dir):
    print(f"'{destination_dir}' 폴더를 생성합니다.")
    os.makedirs(destination_dir)

# 4. 파일 이동 및 이름 변경
source_path = os.path.join(os.getcwd(), source_file)
destination_path = os.path.join(destination_dir, destination_file)

try:
    shutil.move(source_path, destination_path)
    print(f"'{source_file}' 파일이 '{destination_path}' 로 성공적으로 이동되었습니다.")
except FileNotFoundError:
    print(f"오류: '{source_file}' 파일을 찾을 수 없습니다. 현재 폴더에 파일이 있는지 확인해 주세요.")

print("\n파일 이동 작업이 완료되었습니다.")
# Out:
# 구글 드라이브를 마운트합니다...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 'transformed_test_data.csv' 파일이 '/content/drive/MyDrive/hackathon_data/transformed_test_data.csv' 로 성공적으로 이동되었습니다.
#
# 파일 이동 작업이 완료되었습니다.

# %% [markdown]
# 테스트 데이터 경로 지정

# %%
import os
import shutil
from google.colab import drive
import glob

# 1. 구글 드라이브 마운트
# 이 코드를 실행하면 인증 절차를 거쳐야 합니다.
print("구글 드라이브를 마운트합니다...")
drive.mount('/content/drive')

# 2. 파일들을 옮길 목표 경로 지정
# 드라이브 내의 'My Drive'는 '/content/drive/MyDrive' 경로에 연결됩니다.
destination_dir = '/content/drive/MyDrive/hackathon_data/train'

# 3. 목표 폴더가 없으면 생성
if not os.path.exists(destination_dir):
    print(f"'{destination_dir}' 폴더를 생성합니다.")
    os.makedirs(destination_dir)

# 4. 현재 폴더에 있는 '_data.csv'로 끝나는 모든 파일 찾기
source_files = glob.glob('*_data.csv')

# 이동할 파일 목록을 출력하여 확인
print(f"이동할 파일 목록: {source_files}")
print(f"총 {len(source_files)}개의 파일을 찾았습니다.")

# 5. 각 파일을 목표 폴더로 이동
for file_name in source_files:
    source_path = os.path.join(os.getcwd(), file_name)
    destination_path = os.path.join(destination_dir, file_name)

    # 파일 이동
    shutil.move(source_path, destination_path)
    print(f"'{file_name}' -> '{destination_dir}' 로 이동 완료.")

print("\n모든 파일 이동이 성공적으로 완료되었습니다.")
# Out:
# 구글 드라이브를 마운트합니다...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 이동할 파일 목록: ['라그로타_data.csv', '미라시아_data.csv', '연회장_data.csv', '카페테리아_data.csv', 'transformed_test_data.csv', 'processed_data.csv', '화담숲주막_data.csv', '담하_data.csv', '포레스트릿_data.csv', '화담숲카페_data.csv', '느티나무_셀프BBQ_data.csv']
# 총 11개의 파일을 찾았습니다.
# '라그로타_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
# '미라시아_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
# '연회장_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
# '카페테리아_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
# 'transformed_test_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
# 'processed_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
# '화담숲주막_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
# '담하_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
# '포레스트릿_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
# '화담숲카페_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
# '느티나무_셀프BBQ_data.csv' -> '/content/drive/MyDrive/hackathon_data/train' 로 이동 완료.
#
# 모든 파일 이동이 성공적으로 완료되었습니다.

# %% [markdown]
# 테스트 데이터 영업장 기준으로 나누기

# %%
import pandas as pd
import re

try:
    # 1. 'transformed_test_data.csv' 파일 불러오기
    df = pd.read_csv('/content/drive/MyDrive/hackathon_data/transformed_test_data.csv')
    print("파일을 성공적으로 불러왔습니다.")

    # 2. 'restaurant' 열의 고유한 값 확인
    restaurants = df['restaurant'].unique()
    print(f"고유한 레스토랑의 수: {len(restaurants)}")
    print(f"레스토랑 목록: {list(restaurants)}")

    # 3. 각 레스토랑별로 데이터프레임을 분리하고 파일로 저장
    for restaurant in restaurants:
        # 파일 이름에 사용할 수 있도록 특수문자나 공백을 '_'로 대체
        safe_name = re.sub(r'[\\/:*?"<>|]', '', restaurant).replace(' ', '_')

        # 해당 레스토랑의 데이터만 필터링
        restaurant_df = df[df['restaurant'] == restaurant].copy()

        # 새로운 파일 이름 생성
        filename = f"{safe_name}_data.csv"

        # CSV 파일로 저장 (인덱스 제외)
        restaurant_df.to_csv(filename, index=False, encoding='utf-8-sig')

        print(f"'{restaurant}' 데이터를 '{filename}' 파일로 저장했습니다.")

    print("\n모든 레스토랑 데이터가 개별 파일로 성공적으로 분리되었습니다.")

except FileNotFoundError:
    print("오류: 'transformed_test_data.csv' 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
# Out:
# 파일을 성공적으로 불러왔습니다.
# 고유한 레스토랑의 수: 9
# 레스토랑 목록: ['느티나무 셀프BBQ', '담하', '라그로타', '미라시아', '연회장', '카페테리아', '포레스트릿', '화담숲주막', '화담숲카페']
# '느티나무 셀프BBQ' 데이터를 '느티나무_셀프BBQ_data.csv' 파일로 저장했습니다.
# '담하' 데이터를 '담하_data.csv' 파일로 저장했습니다.
# '라그로타' 데이터를 '라그로타_data.csv' 파일로 저장했습니다.
# '미라시아' 데이터를 '미라시아_data.csv' 파일로 저장했습니다.
# '연회장' 데이터를 '연회장_data.csv' 파일로 저장했습니다.
# '카페테리아' 데이터를 '카페테리아_data.csv' 파일로 저장했습니다.
# '포레스트릿' 데이터를 '포레스트릿_data.csv' 파일로 저장했습니다.
# '화담숲주막' 데이터를 '화담숲주막_data.csv' 파일로 저장했습니다.
# '화담숲카페' 데이터를 '화담숲카페_data.csv' 파일로 저장했습니다.
#
# 모든 레스토랑 데이터가 개별 파일로 성공적으로 분리되었습니다.

# %% [markdown]
# 테스트 데이터 경로 지정

# %%
import os
import shutil
from google.colab import drive
import glob

# 1. 구글 드라이브 마운트
print("구글 드라이브를 마운트합니다...")
drive.mount('/content/drive')

# 2. 파일들을 옮길 목표 경로 지정
# 'train'이 아닌 'test' 폴더로 이동합니다.
destination_dir = '/content/drive/MyDrive/hackathon_data/test'

# 3. 목표 폴더가 없으면 생성
if not os.path.exists(destination_dir):
    print(f"'{destination_dir}' 폴더를 생성합니다.")
    os.makedirs(destination_dir)

# 4. 현재 폴더에 있는 '_data.csv'로 끝나는 모든 파일 찾기
source_files = glob.glob('*_data.csv')

# 이동할 파일 목록을 출력하여 확인
print(f"이동할 파일 목록: {source_files}")
print(f"총 {len(source_files)}개의 파일을 찾았습니다.")

# 5. 각 파일을 목표 폴더로 이동
for file_name in source_files:
    source_path = os.path.join(os.getcwd(), file_name)
    destination_path = os.path.join(destination_dir, file_name)

    # 파일 이동
    shutil.move(source_path, destination_path)
    print(f"'{file_name}' -> '{destination_dir}' 로 이동 완료.")

print("\n모든 파일 이동이 성공적으로 완료되었습니다.")
# Out:
# 구글 드라이브를 마운트합니다...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/hackathon_data/test' 폴더를 생성합니다.
# 이동할 파일 목록: ['라그로타_data.csv', '미라시아_data.csv', '연회장_data.csv', '카페테리아_data.csv', '화담숲주막_data.csv', '담하_data.csv', '포레스트릿_data.csv', '화담숲카페_data.csv', '느티나무_셀프BBQ_data.csv']
# 총 9개의 파일을 찾았습니다.
# '라그로타_data.csv' -> '/content/drive/MyDrive/hackathon_data/test' 로 이동 완료.
# '미라시아_data.csv' -> '/content/drive/MyDrive/hackathon_data/test' 로 이동 완료.
# '연회장_data.csv' -> '/content/drive/MyDrive/hackathon_data/test' 로 이동 완료.
# '카페테리아_data.csv' -> '/content/drive/MyDrive/hackathon_data/test' 로 이동 완료.
# '화담숲주막_data.csv' -> '/content/drive/MyDrive/hackathon_data/test' 로 이동 완료.
# '담하_data.csv' -> '/content/drive/MyDrive/hackathon_data/test' 로 이동 완료.
# '포레스트릿_data.csv' -> '/content/drive/MyDrive/hackathon_data/test' 로 이동 완료.
# '화담숲카페_data.csv' -> '/content/drive/MyDrive/hackathon_data/test' 로 이동 완료.
# '느티나무_셀프BBQ_data.csv' -> '/content/drive/MyDrive/hackathon_data/test' 로 이동 완료.
#
# 모든 파일 이동이 성공적으로 완료되었습니다.

# %% [markdown]
# holt-winters 모델(느티나무)

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. 데이터 불러오기
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/느티나무_셀프BBQ_data.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/느티나무_셀프BBQ_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 2. 고유한 메뉴 목록 추출
unique_menus = test_df['menu'].unique()
print(f"\n총 {len(unique_menus)}개의 메뉴에 대해 예측을 시작합니다.")

# 3. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 시작 ---")

    # 해당 메뉴에 대한 훈련/테스트 데이터 필터링
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    test_menu_df = test_df[test_df['menu'] == menu_item].copy()

    # 결측값 포함 행 제거 (날짜 생성 전)
    train_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)
    test_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)

    # 날짜별 'sum' 값 합산 (중복 날짜 제거)
    train_agg = train_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()
    test_agg = test_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()

    if train_agg.empty or test_agg.empty:
        print(f"'{menu_item}' 메뉴의 데이터가 부족하여 예측을 건너뜁니다.")
        continue

    # 날짜 인덱스 생성
    train_agg['date'] = pd.to_datetime(train_agg[['year', 'month', 'day']])
    train_agg.set_index('date', inplace=True)

    test_agg['date'] = pd.to_datetime(test_agg[['year', 'month', 'day']])
    test_agg.set_index('date', inplace=True)

    # 시계열 데이터 선택
    train_series = train_agg['sum']
    test_series = test_agg['sum']

    # 날짜가 비어있는 경우 일별 빈도(D)로 채우기
    train_series = train_series.asfreq('D')
    test_series = test_series.asfreq('D')

    # Holt-Winters 모델 구현 및 훈련
    model = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_model = model.fit()

    # 예측
    forecast_steps = len(test_series)
    predictions = fitted_model.forecast(steps=forecast_steps)

    # 평가
    results_df = pd.DataFrame({
        'actual': test_series,
        'predicted': predictions
    }).dropna()

    if not results_df.empty:
        actual_values = results_df['actual']
        predictions_filtered = results_df['predicted']

        mse = mean_squared_error(actual_values, predictions_filtered)
        rmse = np.sqrt(mse)

        print(f"  예측값 (상위 5개): \n{predictions_filtered.head()}")
        print(f"\n  실제 테스트 데이터 (상위 5개): \n{actual_values.head()}")
        print(f"\n  MSE (Mean Squared Error): {mse:.2f}")
        print(f"  RMSE (Root Mean Squared Error): {rmse:.2f}")
    else:
        print("  예측과 실제값을 비교할 데이터가 부족하여 평가를 건너뜁니다.")

    print(f"\n--- 메뉴: '{menu_item}' 예측 종료 ---\n")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 23개의 메뉴에 대해 예측을 시작합니다.
#
# --- 메뉴: '1인 수저세트' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    5.090443
# 2024-06-17    1.892980
# 2024-06-18    1.959610
# 2024-06-19    2.090763
# 2024-06-20    3.473463
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    4.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 31.63
#   RMSE (Root Mean Squared Error): 5.62
#
# --- 메뉴: '1인 수저세트' 예측 종료 ---
#
#
# --- 메뉴: 'BBQ55(단체)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16     35.605367
# 2024-06-17     58.193626
# 2024-06-18     54.802617
# 2024-06-19     67.540268
# 2024-06-20    106.345163
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16      0.0
# 2024-06-17      0.0
# 2024-06-18      0.0
# 2024-06-19     67.0
# 2024-06-20    124.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 5946.52
#   RMSE (Root Mean Squared Error): 77.11
#
# --- 메뉴: 'BBQ55(단체)' 예측 종료 ---
#
#
# --- 메뉴: '대여료 30,000원' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.622152
# 2024-06-17   -1.039901
# 2024-06-18    0.465500
# 2024-06-19    0.698514
# 2024-06-20    3.929682
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    5.0
# 2024-06-17    0.0
# 2024-06-18    2.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 30.73
#   RMSE (Root Mean Squared Error): 5.54
#
# --- 메뉴: '대여료 30,000원' 예측 종료 ---
#
#
# --- 메뉴: '대여료 60,000원' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.141617
# 2024-06-17   -1.194622
# 2024-06-18   -0.874686
# 2024-06-19    0.264844
# 2024-06-20    0.333401
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    3.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 11.44
#   RMSE (Root Mean Squared Error): 3.38
#
# --- 메뉴: '대여료 60,000원' 예측 종료 ---
#
#
# --- 메뉴: '대여료 90,000원' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.440645
# 2024-06-17    0.035062
# 2024-06-18    0.063120
# 2024-06-19    0.172631
# 2024-06-20    0.243343
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.77
#   RMSE (Root Mean Squared Error): 0.88
#
# --- 메뉴: '대여료 90,000원' 예측 종료 ---
#
#
# --- 메뉴: '본삼겹 (단품,실내)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.402902
# 2024-06-17    0.824654
# 2024-06-18    1.009254
# 2024-06-19    1.114927
# 2024-06-20    1.233759
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    2.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3.98
#   RMSE (Root Mean Squared Error): 1.99
#
# --- 메뉴: '본삼겹 (단품,실내)' 예측 종료 ---
#
#
# --- 메뉴: '스프라이트 (단체)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16     2.193104
# 2024-06-17     9.969455
# 2024-06-18     5.798370
# 2024-06-19    11.087857
# 2024-06-20    25.074691
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     0.0
# 2024-06-17     0.0
# 2024-06-18     2.0
# 2024-06-19    33.0
# 2024-06-20    48.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 287.57
#   RMSE (Root Mean Squared Error): 16.96
#
# --- 메뉴: '스프라이트 (단체)' 예측 종료 ---
#
#
# --- 메뉴: '신라면' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    4.053886
# 2024-06-17    1.976476
# 2024-06-18    4.278034
# 2024-06-19    2.629825
# 2024-06-20    5.170444
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    2.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 48.94
#   RMSE (Root Mean Squared Error): 7.00
#
# --- 메뉴: '신라면' 예측 종료 ---
#
#
# --- 메뉴: '쌈야채세트' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    4.240868
# 2024-06-17    1.901789
# 2024-06-18    2.889595
# 2024-06-19    3.630313
# 2024-06-20    5.468287
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 25.11
#   RMSE (Root Mean Squared Error): 5.01
#
# --- 메뉴: '쌈야채세트' 예측 종료 ---
#
#
# --- 메뉴: '쌈장' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.080613
# 2024-06-17    0.227211
# 2024-06-18    0.301934
# 2024-06-19    0.558242
# 2024-06-20    0.332789
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.86
#   RMSE (Root Mean Squared Error): 0.93
#
# --- 메뉴: '쌈장' 예측 종료 ---
#
#
# --- 메뉴: '육개장 사발면' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.065127
# 2024-06-17    0.275481
# 2024-06-18    0.485968
# 2024-06-19    0.604210
# 2024-06-20    0.775230
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3.14
#   RMSE (Root Mean Squared Error): 1.77
#
# --- 메뉴: '육개장 사발면' 예측 종료 ---
#
#
# --- 메뉴: '일회용 소주컵' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.485838
# 2024-06-17    0.169104
# 2024-06-18    0.288322
# 2024-06-19    0.379742
# 2024-06-20    0.301168
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.43
#   RMSE (Root Mean Squared Error): 0.65
#
# --- 메뉴: '일회용 소주컵' 예측 종료 ---
#
#
# --- 메뉴: '일회용 종이컵' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.156218
# 2024-06-17    0.301035
# 2024-06-18    0.590441
# 2024-06-19    0.511411
# 2024-06-20    0.616709
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.22
#   RMSE (Root Mean Squared Error): 1.11
#
# --- 메뉴: '일회용 종이컵' 예측 종료 ---
#
#
# --- 메뉴: '잔디그늘집 대여료 (12인석)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.309356
# 2024-06-17    0.866629
# 2024-06-18    3.453923
# 2024-06-19    2.797302
# 2024-06-20    4.754280
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    5.0
# 2024-06-17    0.0
# 2024-06-18    3.0
# 2024-06-19    0.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 24.10
#   RMSE (Root Mean Squared Error): 4.91
#
# --- 메뉴: '잔디그늘집 대여료 (12인석)' 예측 종료 ---
#
#
# --- 메뉴: '잔디그늘집 대여료 (6인석)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    12.782494
# 2024-06-17    -0.196481
# 2024-06-18     4.605538
# 2024-06-19     8.834448
# 2024-06-20    16.829205
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    13.0
# 2024-06-17     0.0
# 2024-06-18     2.0
# 2024-06-19     1.0
# 2024-06-20     5.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 473.71
#   RMSE (Root Mean Squared Error): 21.76
#
# --- 메뉴: '잔디그늘집 대여료 (6인석)' 예측 종료 ---
#
#
# --- 메뉴: '잔디그늘집 의자 추가' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.397182
# 2024-06-17    0.652362
# 2024-06-18    0.619368
# 2024-06-19    1.130874
# 2024-06-20    1.756001
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 5.06
#   RMSE (Root Mean Squared Error): 2.25
#
# --- 메뉴: '잔디그늘집 의자 추가' 예측 종료 ---
#
#
# --- 메뉴: '참이슬 (단체)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    12.694836
# 2024-06-17    35.326074
# 2024-06-18    24.286770
# 2024-06-19    40.774867
# 2024-06-20    72.534292
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     0.0
# 2024-06-17     0.0
# 2024-06-18    31.0
# 2024-06-19    18.0
# 2024-06-20    81.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1914.40
#   RMSE (Root Mean Squared Error): 43.75
#
# --- 메뉴: '참이슬 (단체)' 예측 종료 ---
#
#
# --- 메뉴: '친환경 접시 14cm' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.662352
# 2024-06-17    0.122855
# 2024-06-18    0.386017
# 2024-06-19    0.372871
# 2024-06-20    0.346546
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.82
#   RMSE (Root Mean Squared Error): 0.91
#
# --- 메뉴: '친환경 접시 14cm' 예측 종료 ---
#
#
# --- 메뉴: '친환경 접시 23cm' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.511455
# 2024-06-17    0.564090
# 2024-06-18    0.524587
# 2024-06-19    0.682535
# 2024-06-20    0.840408
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.41
#   RMSE (Root Mean Squared Error): 1.19
#
# --- 메뉴: '친환경 접시 23cm' 예측 종료 ---
#
#
# --- 메뉴: '카스 병(단체)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    21.665468
# 2024-06-17    46.085723
# 2024-06-18    36.074535
# 2024-06-19    52.238543
# 2024-06-20    90.130619
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     0.0
# 2024-06-17     0.0
# 2024-06-18    20.0
# 2024-06-19    18.0
# 2024-06-20    95.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3123.66
#   RMSE (Root Mean Squared Error): 55.89
#
# --- 메뉴: '카스 병(단체)' 예측 종료 ---
#
#
# --- 메뉴: '콜라 (단체)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16     2.882083
# 2024-06-17    11.307847
# 2024-06-18     7.686612
# 2024-06-19    12.896813
# 2024-06-20    24.515636
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     0.0
# 2024-06-17     0.0
# 2024-06-18     2.0
# 2024-06-19    34.0
# 2024-06-20    50.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 283.57
#   RMSE (Root Mean Squared Error): 16.84
#
# --- 메뉴: '콜라 (단체)' 예측 종료 ---
#
#
# --- 메뉴: '햇반' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.280567
# 2024-06-17    0.379847
# 2024-06-18    1.182231
# 2024-06-19    1.512435
# 2024-06-20    2.138050
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 7.77
#   RMSE (Root Mean Squared Error): 2.79
#
# --- 메뉴: '햇반' 예측 종료 ---
#
#
# --- 메뉴: '허브솔트' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.401317
# 2024-06-17    0.164835
# 2024-06-18    0.262926
# 2024-06-19    0.440375
# 2024-06-20    0.228530
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.73
#   RMSE (Root Mean Squared Error): 0.85
#
# --- 메뉴: '허브솔트' 예측 종료 ---

# %% [markdown]
# 느티나무 영업장의 submission 파일 생성

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np
import warnings
from datetime import timedelta

# statsmodels 경고 무시
warnings.filterwarnings("ignore")

# 1. 데이터 불러오기 및 전처리
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/느티나무_셀프BBQ_data.csv')
    test_df_original = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/느티나무_셀프BBQ_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 날짜/시간 인덱스 생성
train_df['date'] = pd.to_datetime(train_df[['year', 'month', 'day']])
test_df_original['date'] = pd.to_datetime(test_df_original[['year', 'month', 'day']])

# 결측값 포함 행 제거
train_df.dropna(subset=['date', 'sum'], inplace=True)
test_df_original.dropna(subset=['date', 'sum'], inplace=True)

# 2. 예측 대상 날짜들 찾기 (모든 메뉴에 대해 공통)
# 테스트 데이터의 전체 날짜 범위
full_test_date_range = pd.date_range(
    start=test_df_original['date'].min(),
    end=test_df_original['date'].max(),
    freq='D'
)

# 테스트 데이터에 실제 값이 존재하는 날짜
dates_with_data = pd.to_datetime(test_df_original['date'].unique())

# 전체 날짜 범위에서 실제 데이터가 있는 날짜를 제외하여 빈 기간 식별
missing_dates = full_test_date_range.difference(dates_with_data)

# 마지막 7일 기간 추가 (테스트 데이터 마지막 날 다음 날부터)
last_test_date = test_df_original['date'].max()
final_week_dates = pd.date_range(
    start=last_test_date + timedelta(days=1),
    periods=7,
    freq='D'
)

# 예측할 날짜 전체 리스트 생성
forecast_dates = missing_dates.append(final_week_dates).sort_values()

# 예측할 날짜 목록 출력
print(f"\n총 {len(forecast_dates)}개의 날짜에 대해 예측을 수행합니다.")
print("예측 날짜 목록:")
print(forecast_dates)

# 3. 고유한 메뉴 목록 추출 및 예측
unique_menus = test_df_original['menu'].unique()
predictions_dict = {}

# 4. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 진행 중... ---")

    # 해당 메뉴에 대한 훈련 데이터 필터링 및 합산
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    train_series = train_menu_df.groupby('date')['sum'].sum().asfreq('D')

    if train_series.empty:
        predictions_dict[menu_item] = np.zeros(len(forecast_dates))
        print(f"  데이터 부족으로 '{menu_item}' 예측값을 0으로 처리합니다.")
        continue

    # Holt-Winters 모델 훈련
    model_hw = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_hw = model_hw.fit()

    # 예측 수행
    menu_predictions_series = fitted_hw.predict(
        start=forecast_dates.min(),
        end=forecast_dates.max()
    )

    # 예측값을 빈 날짜에 맞게 필터링
    final_predictions_for_menu = menu_predictions_series.reindex(forecast_dates)

    # 예측값 저장
    predictions_dict[menu_item] = final_predictions_for_menu.values

# 5. 예측값으로 최종 데이터프레임 생성
final_predictions_df = pd.DataFrame(predictions_dict, index=forecast_dates)

# 열 라벨(column labels) 생성
column_labels = [f"느티나무_셀프BBQ_{menu}" for menu in unique_menus]
final_predictions_df.columns = column_labels

# 6. 예측 파일로 저장
file_name = 'test_predictions_by_date.csv'
final_predictions_df.to_csv(file_name, encoding='utf-8-sig', index=True)

print(f"\n성공적으로 예측이 완료되었습니다. 결과는 '{file_name}' 파일에 저장되었습니다.")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 70개의 날짜에 대해 예측을 수행합니다.
# 예측 날짜 목록:
# DatetimeIndex(['2024-07-14', '2024-07-15', '2024-07-16', '2024-07-17',
#                '2024-07-18', '2024-07-19', '2024-07-20', '2024-08-18',
#                '2024-08-19', '2024-08-20', '2024-08-21', '2024-08-22',
#                '2024-08-23', '2024-08-24', '2024-09-22', '2024-09-23',
#                '2024-09-24', '2024-09-25', '2024-09-26', '2024-09-27',
#                '2024-09-28', '2024-10-27', '2024-10-28', '2024-10-29',
#                '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-02',
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2025-01-05',
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-09',
#                '2025-01-10', '2025-01-11', '2025-02-09', '2025-02-10',
#                '2025-02-11', '2025-02-12', '2025-02-13', '2025-02-14',
#                '2025-02-15', '2025-03-16', '2025-03-17', '2025-03-18',
#                '2025-03-19', '2025-03-20', '2025-03-21', '2025-03-22',
#                '2025-04-20', '2025-04-21', '2025-04-22', '2025-04-23',
#                '2025-04-24', '2025-04-25', '2025-04-26', '2025-05-25',
#                '2025-05-26', '2025-05-27', '2025-05-28', '2025-05-29',
#                '2025-05-30', '2025-05-31'],
#               dtype='datetime64[ns]', freq=None)
#
# --- 메뉴: '1인 수저세트' 예측 진행 중... ---
#
# --- 메뉴: 'BBQ55(단체)' 예측 진행 중... ---
#
# --- 메뉴: '대여료 30,000원' 예측 진행 중... ---
#
# --- 메뉴: '대여료 60,000원' 예측 진행 중... ---
#
# --- 메뉴: '대여료 90,000원' 예측 진행 중... ---
#
# --- 메뉴: '본삼겹 (단품,실내)' 예측 진행 중... ---
#
# --- 메뉴: '스프라이트 (단체)' 예측 진행 중... ---
#
# --- 메뉴: '신라면' 예측 진행 중... ---
#
# --- 메뉴: '쌈야채세트' 예측 진행 중... ---
#
# --- 메뉴: '쌈장' 예측 진행 중... ---
#
# --- 메뉴: '육개장 사발면' 예측 진행 중... ---
#
# --- 메뉴: '일회용 소주컵' 예측 진행 중... ---
#
# --- 메뉴: '일회용 종이컵' 예측 진행 중... ---
#
# --- 메뉴: '잔디그늘집 대여료 (12인석)' 예측 진행 중... ---
#
# --- 메뉴: '잔디그늘집 대여료 (6인석)' 예측 진행 중... ---
#
# --- 메뉴: '잔디그늘집 의자 추가' 예측 진행 중... ---
#
# --- 메뉴: '참이슬 (단체)' 예측 진행 중... ---
#
# --- 메뉴: '친환경 접시 14cm' 예측 진행 중... ---
#
# --- 메뉴: '친환경 접시 23cm' 예측 진행 중... ---
#
# --- 메뉴: '카스 병(단체)' 예측 진행 중... ---
#
# --- 메뉴: '콜라 (단체)' 예측 진행 중... ---
#
# --- 메뉴: '햇반' 예측 진행 중... ---
#
# --- 메뉴: '허브솔트' 예측 진행 중... ---
#
# 성공적으로 예측이 완료되었습니다. 결과는 'test_predictions_by_date.csv' 파일에 저장되었습니다.

# %% [markdown]
# holt-winters 모델(담하)

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. 데이터 불러오기
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/담하_data.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/담하_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 2. 고유한 메뉴 목록 추출
unique_menus = test_df['menu'].unique()
print(f"\n총 {len(unique_menus)}개의 메뉴에 대해 예측을 시작합니다.")

# 3. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 시작 ---")

    # 해당 메뉴에 대한 훈련/테스트 데이터 필터링
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    test_menu_df = test_df[test_df['menu'] == menu_item].copy()

    # 결측값 포함 행 제거 (날짜 생성 전)
    train_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)
    test_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)

    # 날짜별 'sum' 값 합산 (중복 날짜 제거)
    train_agg = train_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()
    test_agg = test_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()

    if train_agg.empty or test_agg.empty:
        print(f"'{menu_item}' 메뉴의 데이터가 부족하여 예측을 건너뜁니다.")
        continue

    # 날짜 인덱스 생성
    train_agg['date'] = pd.to_datetime(train_agg[['year', 'month', 'day']])
    train_agg.set_index('date', inplace=True)

    test_agg['date'] = pd.to_datetime(test_agg[['year', 'month', 'day']])
    test_agg.set_index('date', inplace=True)

    # 시계열 데이터 선택
    train_series = train_agg['sum']
    test_series = test_agg['sum']

    # 날짜가 비어있는 경우 일별 빈도(D)로 채우기
    train_series = train_series.asfreq('D')
    test_series = test_series.asfreq('D')

    # Holt-Winters 모델 구현 및 훈련
    model = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_model = model.fit()

    # 예측
    forecast_steps = len(test_series)
    predictions = fitted_model.forecast(steps=forecast_steps)

    # 평가
    results_df = pd.DataFrame({
        'actual': test_series,
        'predicted': predictions
    }).dropna()

    if not results_df.empty:
        actual_values = results_df['actual']
        predictions_filtered = results_df['predicted']

        mse = mean_squared_error(actual_values, predictions_filtered)
        rmse = np.sqrt(mse)

        print(f"  예측값 (상위 5개): \n{predictions_filtered.head()}")
        print(f"\n  실제 테스트 데이터 (상위 5개): \n{actual_values.head()}")
        print(f"\n  MSE (Mean Squared Error): {mse:.2f}")
        print(f"  RMSE (Root Mean Squared Error): {rmse:.2f}")
    else:
        print("  예측과 실제값을 비교할 데이터가 부족하여 평가를 건너뜁니다.")

    print(f"\n--- 메뉴: '{menu_item}' 예측 종료 ---\n")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 42개의 메뉴에 대해 예측을 시작합니다.
#
# --- 메뉴: '(단체) 공깃밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.056064
# 2024-06-17    0.822309
# 2024-06-18    0.505818
# 2024-06-19    0.915337
# 2024-06-20    1.048507
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    2.0
# 2024-06-19    3.0
# 2024-06-20    4.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 4.08
#   RMSE (Root Mean Squared Error): 2.02
#
# --- 메뉴: '(단체) 공깃밥' 예측 종료 ---
#
#
# --- 메뉴: '(단체) 생목살 김치전골 2.0' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16     4.143922
# 2024-06-17    10.062939
# 2024-06-18    19.231363
# 2024-06-19    20.015807
# 2024-06-20    18.837762
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16      0.0
# 2024-06-17      0.0
# 2024-06-18      0.0
# 2024-06-19    129.0
# 2024-06-20     17.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 672.71
#   RMSE (Root Mean Squared Error): 25.94
#
# --- 메뉴: '(단체) 생목살 김치전골 2.0' 예측 종료 ---
#
#
# --- 메뉴: '(단체) 은이버섯 갈비탕' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16     4.465173
# 2024-06-17     9.807841
# 2024-06-18     9.372757
# 2024-06-19    11.228429
# 2024-06-20    13.872930
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     0.0
# 2024-06-17     0.0
# 2024-06-18    18.0
# 2024-06-19     0.0
# 2024-06-20     0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 565.17
#   RMSE (Root Mean Squared Error): 23.77
#
# --- 메뉴: '(단체) 은이버섯 갈비탕' 예측 종료 ---
#
#
# --- 메뉴: '(단체) 한우 우거지 국밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.502122
# 2024-06-17    2.765269
# 2024-06-18    5.146847
# 2024-06-19    6.081046
# 2024-06-20    9.357356
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 209.72
#   RMSE (Root Mean Squared Error): 14.48
#
# --- 메뉴: '(단체) 한우 우거지 국밥' 예측 종료 ---
#
#
# --- 메뉴: '(단체) 황태해장국 3/27까지' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16     8.071123
# 2024-06-17     5.365147
# 2024-06-18    43.815567
# 2024-06-19    27.019910
# 2024-06-20    35.729706
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     90.0
# 2024-06-17      0.0
# 2024-06-18     23.0
# 2024-06-19    108.0
# 2024-06-20     37.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1842.40
#   RMSE (Root Mean Squared Error): 42.92
#
# --- 메뉴: '(단체) 황태해장국 3/27까지' 예측 종료 ---
#
#
# --- 메뉴: '(정식) 된장찌개' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    6.967754
# 2024-06-17    4.454339
# 2024-06-18    4.480616
# 2024-06-19    2.914933
# 2024-06-20    4.217374
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    4.0
# 2024-06-17    5.0
# 2024-06-18    2.0
# 2024-06-19    0.0
# 2024-06-20    3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 76.98
#   RMSE (Root Mean Squared Error): 8.77
#
# --- 메뉴: '(정식) 된장찌개' 예측 종료 ---
#
#
# --- 메뉴: '(정식) 물냉면 ' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    4.990765
# 2024-06-17    3.096201
# 2024-06-18    3.543619
# 2024-06-19    2.779964
# 2024-06-20    3.398544
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    1.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 17.03
#   RMSE (Root Mean Squared Error): 4.13
#
# --- 메뉴: '(정식) 물냉면 ' 예측 종료 ---
#
#
# --- 메뉴: '(정식) 비빔냉면' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    4.710062
# 2024-06-17    3.157471
# 2024-06-18    3.670711
# 2024-06-19    2.697059
# 2024-06-20    3.499597
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    1.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 17.80
#   RMSE (Root Mean Squared Error): 4.22
#
# --- 메뉴: '(정식) 비빔냉면' 예측 종료 ---
#
#
# --- 메뉴: '(후식) 된장찌개' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.421793
# 2024-06-17    0.119137
# 2024-06-18   -0.367608
# 2024-06-19    0.092888
# 2024-06-20    0.566356
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    2.0
# 2024-06-19    0.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 19.77
#   RMSE (Root Mean Squared Error): 4.45
#
# --- 메뉴: '(후식) 된장찌개' 예측 종료 ---
#
#
# --- 메뉴: '(후식) 물냉면' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.161100
# 2024-06-17    2.397947
# 2024-06-18    2.147945
# 2024-06-19    2.345310
# 2024-06-20    3.147937
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    4.0
# 2024-06-19    2.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 8.46
#   RMSE (Root Mean Squared Error): 2.91
#
# --- 메뉴: '(후식) 물냉면' 예측 종료 ---
#
#
# --- 메뉴: '(후식) 비빔냉면' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.102317
# 2024-06-17    1.891668
# 2024-06-18    1.602244
# 2024-06-19    1.641331
# 2024-06-20    1.996648
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    4.0
# 2024-06-19    1.0
# 2024-06-20    6.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 5.15
#   RMSE (Root Mean Squared Error): 2.27
#
# --- 메뉴: '(후식) 비빔냉면' 예측 종료 ---
#
#
# --- 메뉴: '갑오징어 비빔밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.125555
# 2024-06-17    0.308892
# 2024-06-18   -0.269965
# 2024-06-19   -0.703744
# 2024-06-20    0.019735
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.45
#   RMSE (Root Mean Squared Error): 0.67
#
# --- 메뉴: '갑오징어 비빔밥' 예측 종료 ---
#
#
# --- 메뉴: '갱시기' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    5.773001
# 2024-06-17    0.801192
# 2024-06-18    0.899984
# 2024-06-19    0.624187
# 2024-06-20    0.493782
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 9.95
#   RMSE (Root Mean Squared Error): 3.15
#
# --- 메뉴: '갱시기' 예측 종료 ---
#
#
# --- 메뉴: '공깃밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    24.443050
# 2024-06-17     9.115640
# 2024-06-18     2.221923
# 2024-06-19     3.153807
# 2024-06-20     5.652167
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    22.0
# 2024-06-17     7.0
# 2024-06-18    11.0
# 2024-06-19    10.0
# 2024-06-20     7.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1231.21
#   RMSE (Root Mean Squared Error): 35.09
#
# --- 메뉴: '공깃밥' 예측 종료 ---
#
#
# --- 메뉴: '꼬막 비빔밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.275389
# 2024-06-17    0.019708
# 2024-06-18   -0.283220
# 2024-06-19   -0.606071
# 2024-06-20   -0.517503
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 32.65
#   RMSE (Root Mean Squared Error): 5.71
#
# --- 메뉴: '꼬막 비빔밥' 예측 종료 ---
#
#
# --- 메뉴: '느린마을 막걸리' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.499230
# 2024-06-17    1.130765
# 2024-06-18    1.078155
# 2024-06-19    0.972817
# 2024-06-20    1.038688
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    2.0
# 2024-06-18    1.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 4.29
#   RMSE (Root Mean Squared Error): 2.07
#
# --- 메뉴: '느린마을 막걸리' 예측 종료 ---
#
#
# --- 메뉴: '담하 한우 불고기' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    12.993984
# 2024-06-17     3.106423
# 2024-06-18     1.035231
# 2024-06-19     2.707627
# 2024-06-20    10.709020
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     7.0
# 2024-06-17     5.0
# 2024-06-18    12.0
# 2024-06-19     8.0
# 2024-06-20     6.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 855.65
#   RMSE (Root Mean Squared Error): 29.25
#
# --- 메뉴: '담하 한우 불고기' 예측 종료 ---
#
#
# --- 메뉴: '담하 한우 불고기 정식' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    14.385836
# 2024-06-17     7.676385
# 2024-06-18     9.437880
# 2024-06-19     4.530860
# 2024-06-20     7.291424
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    9.0
# 2024-06-17    5.0
# 2024-06-18    2.0
# 2024-06-19    0.0
# 2024-06-20    4.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 139.03
#   RMSE (Root Mean Squared Error): 11.79
#
# --- 메뉴: '담하 한우 불고기 정식' 예측 종료 ---
#
#
# --- 메뉴: '더덕 한우 지짐' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.354797
# 2024-06-17    1.315304
# 2024-06-18    1.262636
# 2024-06-19    1.302128
# 2024-06-20    1.591566
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    3.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3.46
#   RMSE (Root Mean Squared Error): 1.86
#
# --- 메뉴: '더덕 한우 지짐' 예측 종료 ---
#
#
# --- 메뉴: '들깨 양지탕' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.530412
# 2024-06-17   -0.806799
# 2024-06-18   -0.083206
# 2024-06-19   -1.319764
# 2024-06-20   -0.319754
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 18.40
#   RMSE (Root Mean Squared Error): 4.29
#
# --- 메뉴: '들깨 양지탕' 예측 종료 ---
#
#
# --- 메뉴: '라면사리' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.668184
# 2024-06-17    1.523454
# 2024-06-18    1.102387
# 2024-06-19    0.944510
# 2024-06-20    2.510292
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     0.0
# 2024-06-17     0.0
# 2024-06-18     0.0
# 2024-06-19    12.0
# 2024-06-20     0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 13.98
#   RMSE (Root Mean Squared Error): 3.74
#
# --- 메뉴: '라면사리' 예측 종료 ---
#
#
# --- 메뉴: '룸 이용료' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.019599
# 2024-06-17    0.141235
# 2024-06-18    0.376315
# 2024-06-19    0.078467
# 2024-06-20    0.833873
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    4.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.85
#   RMSE (Root Mean Squared Error): 0.92
#
# --- 메뉴: '룸 이용료' 예측 종료 ---
#
#
# --- 메뉴: '메밀면 사리' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.946128
# 2024-06-17    0.642064
# 2024-06-18   -0.252224
# 2024-06-19   -0.159554
# 2024-06-20    0.037917
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    1.0
# 2024-06-18    0.0
# 2024-06-19    2.0
# 2024-06-20    2.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 10.89
#   RMSE (Root Mean Squared Error): 3.30
#
# --- 메뉴: '메밀면 사리' 예측 종료 ---
#
#
# --- 메뉴: '명인안동소주' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.305672
# 2024-06-17    0.437319
# 2024-06-18    0.253052
# 2024-06-19    0.318787
# 2024-06-20    0.410778
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.65
#   RMSE (Root Mean Squared Error): 0.81
#
# --- 메뉴: '명인안동소주' 예측 종료 ---
#
#
# --- 메뉴: '명태회 비빔냉면' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.954860
# 2024-06-17    3.481383
# 2024-06-18    3.362951
# 2024-06-19    3.533918
# 2024-06-20    3.507511
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    8.0
# 2024-06-17    0.0
# 2024-06-18    2.0
# 2024-06-19    0.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 14.24
#   RMSE (Root Mean Squared Error): 3.77
#
# --- 메뉴: '명태회 비빔냉면' 예측 종료 ---
#
#
# --- 메뉴: '문막 복분자 칵테일' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.483352
# 2024-06-17    0.443869
# 2024-06-18    0.404378
# 2024-06-19    0.364907
# 2024-06-20    0.417536
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    5.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.69
#   RMSE (Root Mean Squared Error): 1.30
#
# --- 메뉴: '문막 복분자 칵테일' 예측 종료 ---
#
#
# --- 메뉴: '봉평메밀 물냉면' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.500478
# 2024-06-17    0.660118
# 2024-06-18    1.439172
# 2024-06-19    4.032904
# 2024-06-20    2.443512
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    8.0
# 2024-06-17    0.0
# 2024-06-18    2.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 11.64
#   RMSE (Root Mean Squared Error): 3.41
#
# --- 메뉴: '봉평메밀 물냉면' 예측 종료 ---
#
#
# --- 메뉴: '생목살 김치찌개' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    10.992620
# 2024-06-17     5.533423
# 2024-06-18     5.174375
# 2024-06-19     5.004862
# 2024-06-20     4.460185
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    16.0
# 2024-06-17     5.0
# 2024-06-18     0.0
# 2024-06-19    12.0
# 2024-06-20     6.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 357.48
#   RMSE (Root Mean Squared Error): 18.91
#
# --- 메뉴: '생목살 김치찌개' 예측 종료 ---
#
#
# --- 메뉴: '스프라이트' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.550193
# 2024-06-17    0.708094
# 2024-06-18    0.773822
# 2024-06-19   -0.094512
# 2024-06-20    0.708114
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.73
#   RMSE (Root Mean Squared Error): 1.32
#
# --- 메뉴: '스프라이트' 예측 종료 ---
#
#
# --- 메뉴: '은이버섯 갈비탕' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    4.185353
# 2024-06-17    3.870162
# 2024-06-18    2.724963
# 2024-06-19    3.251001
# 2024-06-20    3.566990
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    5.0
# 2024-06-17    2.0
# 2024-06-18    3.0
# 2024-06-19    1.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 56.60
#   RMSE (Root Mean Squared Error): 7.52
#
# --- 메뉴: '은이버섯 갈비탕' 예측 종료 ---
#
#
# --- 메뉴: '제로콜라' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.497512
# 2024-06-17    0.286989
# 2024-06-18    0.023828
# 2024-06-19    0.326470
# 2024-06-20    0.484363
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.33
#   RMSE (Root Mean Squared Error): 1.16
#
# --- 메뉴: '제로콜라' 예측 종료 ---
#
#
# --- 메뉴: '참이슬' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.708745
# 2024-06-17    1.248257
# 2024-06-18    1.103599
# 2024-06-19    0.787595
# 2024-06-20    1.116463
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    1.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 9.81
#   RMSE (Root Mean Squared Error): 3.13
#
# --- 메뉴: '참이슬' 예측 종료 ---
#
#
# --- 메뉴: '처음처럼' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.577229
# 2024-06-17    0.458868
# 2024-06-18    0.380515
# 2024-06-19    0.183031
# 2024-06-20    0.485729
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.48
#   RMSE (Root Mean Squared Error): 1.22
#
# --- 메뉴: '처음처럼' 예측 종료 ---
#
#
# --- 메뉴: '카스' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.972988
# 2024-06-17    0.604541
# 2024-06-18    0.709784
# 2024-06-19    0.801894
# 2024-06-20    0.630851
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    5.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 6.25
#   RMSE (Root Mean Squared Error): 2.50
#
# --- 메뉴: '카스' 예측 종료 ---
#
#
# --- 메뉴: '콜라' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.440919
# 2024-06-17    0.112108
# 2024-06-18    0.112097
# 2024-06-19   -0.137861
# 2024-06-20    0.375360
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2.46
#   RMSE (Root Mean Squared Error): 1.57
#
# --- 메뉴: '콜라' 예측 종료 ---
#
#
# --- 메뉴: '테라' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.727552
# 2024-06-17    0.832857
# 2024-06-18    1.043381
# 2024-06-19    0.411857
# 2024-06-20    0.688078
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    1.0
# 2024-06-18    0.0
# 2024-06-19    3.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.89
#   RMSE (Root Mean Squared Error): 1.38
#
# --- 메뉴: '테라' 예측 종료 ---
#
#
# --- 메뉴: '하동 매실 칵테일' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.819581
# 2024-06-17    0.293218
# 2024-06-18    0.214341
# 2024-06-19    0.201165
# 2024-06-20    0.424814
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.35
#   RMSE (Root Mean Squared Error): 1.16
#
# --- 메뉴: '하동 매실 칵테일' 예측 종료 ---
#
#
# --- 메뉴: '한우 떡갈비 정식' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    10.519672
# 2024-06-17     4.869485
# 2024-06-18     4.408474
# 2024-06-19     4.838018
# 2024-06-20     4.688428
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    13.0
# 2024-06-17     5.0
# 2024-06-18     1.0
# 2024-06-19     3.0
# 2024-06-20     3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 101.10
#   RMSE (Root Mean Squared Error): 10.05
#
# --- 메뉴: '한우 떡갈비 정식' 예측 종료 ---
#
#
# --- 메뉴: '한우 미역국 정식' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    11.601987
# 2024-06-17     6.207229
# 2024-06-18     3.536242
# 2024-06-19     2.510106
# 2024-06-20     2.733721
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    12.0
# 2024-06-17     2.0
# 2024-06-18     1.0
# 2024-06-19     0.0
# 2024-06-20     3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 59.82
#   RMSE (Root Mean Squared Error): 7.73
#
# --- 메뉴: '한우 미역국 정식' 예측 종료 ---
#
#
# --- 메뉴: '한우 우거지 국밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    17.371291
# 2024-06-17     7.924182
# 2024-06-18     4.068763
# 2024-06-19     4.568693
# 2024-06-20     4.081893
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    12.0
# 2024-06-17     1.0
# 2024-06-18     1.0
# 2024-06-19     0.0
# 2024-06-20    10.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 78.90
#   RMSE (Root Mean Squared Error): 8.88
#
# --- 메뉴: '한우 우거지 국밥' 예측 종료 ---
#
#
# --- 메뉴: '한우 차돌박이 된장찌개' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    9.297691
# 2024-06-17    5.822763
# 2024-06-18    5.362795
# 2024-06-19    3.981282
# 2024-06-20    6.402101
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    18.0
# 2024-06-17     6.0
# 2024-06-18     0.0
# 2024-06-19     5.0
# 2024-06-20    11.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 127.03
#   RMSE (Root Mean Squared Error): 11.27
#
# --- 메뉴: '한우 차돌박이 된장찌개' 예측 종료 ---
#
#
# --- 메뉴: '황태해장국' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    11.362227
# 2024-06-17     4.151952
# 2024-06-18     4.875535
# 2024-06-19     2.454477
# 2024-06-20     2.257216
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    9.0
# 2024-06-17    1.0
# 2024-06-18    6.0
# 2024-06-19    0.0
# 2024-06-20    2.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 117.25
#   RMSE (Root Mean Squared Error): 10.83
#
# --- 메뉴: '황태해장국' 예측 종료 ---

# %% [markdown]
# 담하 영업장의 submission 파일 생성
#
# > Add blockquote

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np
import warnings
from datetime import timedelta

# statsmodels 경고 무시
warnings.filterwarnings("ignore")

# 1. 데이터 불러오기 및 전처리
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/담하_data.csv')
    test_df_original = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/담하_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 날짜/시간 인덱스 생성
train_df['date'] = pd.to_datetime(train_df[['year', 'month', 'day']])
test_df_original['date'] = pd.to_datetime(test_df_original[['year', 'month', 'day']])

# 결측값 포함 행 제거
train_df.dropna(subset=['date', 'sum'], inplace=True)
test_df_original.dropna(subset=['date', 'sum'], inplace=True)

# 2. 예측 대상 날짜들 찾기 (모든 메뉴에 대해 공통)
# 테스트 데이터의 전체 날짜 범위
full_test_date_range = pd.date_range(
    start=test_df_original['date'].min(),
    end=test_df_original['date'].max(),
    freq='D'
)

# 테스트 데이터에 실제 값이 존재하는 날짜
dates_with_data = pd.to_datetime(test_df_original['date'].unique())

# 전체 날짜 범위에서 실제 데이터가 있는 날짜를 제외하여 빈 기간 식별
missing_dates = full_test_date_range.difference(dates_with_data)

# 마지막 7일 기간 추가 (테스트 데이터 마지막 날 다음 날부터)
last_test_date = test_df_original['date'].max()
final_week_dates = pd.date_range(
    start=last_test_date + timedelta(days=1),
    periods=7,
    freq='D'
)

# 예측할 날짜 전체 리스트 생성
forecast_dates = missing_dates.append(final_week_dates).sort_values()

# 예측할 날짜 목록 출력
print(f"\n총 {len(forecast_dates)}개의 날짜에 대해 예측을 수행합니다.")
print("예측 날짜 목록:")
print(forecast_dates)

# 3. 고유한 메뉴 목록 추출 및 예측
unique_menus = test_df_original['menu'].unique()
predictions_dict = {}

# 4. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 진행 중... ---")

    # 해당 메뉴에 대한 훈련 데이터 필터링 및 합산
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    train_series = train_menu_df.groupby('date')['sum'].sum().asfreq('D')

    if train_series.empty:
        predictions_dict[menu_item] = np.zeros(len(forecast_dates))
        print(f"  데이터 부족으로 '{menu_item}' 예측값을 0으로 처리합니다.")
        continue

    # Holt-Winters 모델 훈련
    model_hw = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_hw = model_hw.fit()

    # 예측 수행
    menu_predictions_series = fitted_hw.predict(
        start=forecast_dates.min(),
        end=forecast_dates.max()
    )

    # 예측값을 빈 날짜에 맞게 필터링
    final_predictions_for_menu = menu_predictions_series.reindex(forecast_dates)

    # 예측값 저장
    predictions_dict[menu_item] = final_predictions_for_menu.values

# 5. 예측값으로 최종 데이터프레임 생성
final_predictions_df = pd.DataFrame(predictions_dict, index=forecast_dates)

# 열 라벨(column labels) 생성
column_labels = [f"담하_{menu}" for menu in unique_menus]
final_predictions_df.columns = column_labels

# 6. 예측 파일로 저장
file_name = 'test_predictions_by_date.csv'
final_predictions_df.to_csv(file_name, encoding='utf-8-sig', index=True)

print(f"\n성공적으로 예측이 완료되었습니다. 결과는 '{file_name}' 파일에 저장되었습니다.")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 70개의 날짜에 대해 예측을 수행합니다.
# 예측 날짜 목록:
# DatetimeIndex(['2024-07-14', '2024-07-15', '2024-07-16', '2024-07-17',
#                '2024-07-18', '2024-07-19', '2024-07-20', '2024-08-18',
#                '2024-08-19', '2024-08-20', '2024-08-21', '2024-08-22',
#                '2024-08-23', '2024-08-24', '2024-09-22', '2024-09-23',
#                '2024-09-24', '2024-09-25', '2024-09-26', '2024-09-27',
#                '2024-09-28', '2024-10-27', '2024-10-28', '2024-10-29',
#                '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-02',
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2025-01-05',
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-09',
#                '2025-01-10', '2025-01-11', '2025-02-09', '2025-02-10',
#                '2025-02-11', '2025-02-12', '2025-02-13', '2025-02-14',
#                '2025-02-15', '2025-03-16', '2025-03-17', '2025-03-18',
#                '2025-03-19', '2025-03-20', '2025-03-21', '2025-03-22',
#                '2025-04-20', '2025-04-21', '2025-04-22', '2025-04-23',
#                '2025-04-24', '2025-04-25', '2025-04-26', '2025-05-25',
#                '2025-05-26', '2025-05-27', '2025-05-28', '2025-05-29',
#                '2025-05-30', '2025-05-31'],
#               dtype='datetime64[ns]', freq=None)
#
# --- 메뉴: '(단체) 공깃밥' 예측 진행 중... ---
#
# --- 메뉴: '(단체) 생목살 김치전골 2.0' 예측 진행 중... ---
#
# --- 메뉴: '(단체) 은이버섯 갈비탕' 예측 진행 중... ---
#
# --- 메뉴: '(단체) 한우 우거지 국밥' 예측 진행 중... ---
#
# --- 메뉴: '(단체) 황태해장국 3/27까지' 예측 진행 중... ---
#
# --- 메뉴: '(정식) 된장찌개' 예측 진행 중... ---
#
# --- 메뉴: '(정식) 물냉면 ' 예측 진행 중... ---
#
# --- 메뉴: '(정식) 비빔냉면' 예측 진행 중... ---
#
# --- 메뉴: '(후식) 된장찌개' 예측 진행 중... ---
#
# --- 메뉴: '(후식) 물냉면' 예측 진행 중... ---
#
# --- 메뉴: '(후식) 비빔냉면' 예측 진행 중... ---
#
# --- 메뉴: '갑오징어 비빔밥' 예측 진행 중... ---
#
# --- 메뉴: '갱시기' 예측 진행 중... ---
#
# --- 메뉴: '공깃밥' 예측 진행 중... ---
#
# --- 메뉴: '꼬막 비빔밥' 예측 진행 중... ---
#
# --- 메뉴: '느린마을 막걸리' 예측 진행 중... ---
#
# --- 메뉴: '담하 한우 불고기' 예측 진행 중... ---
#
# --- 메뉴: '담하 한우 불고기 정식' 예측 진행 중... ---
#
# --- 메뉴: '더덕 한우 지짐' 예측 진행 중... ---
#
# --- 메뉴: '들깨 양지탕' 예측 진행 중... ---
#
# --- 메뉴: '라면사리' 예측 진행 중... ---
#
# --- 메뉴: '룸 이용료' 예측 진행 중... ---
#
# --- 메뉴: '메밀면 사리' 예측 진행 중... ---
#
# --- 메뉴: '명인안동소주' 예측 진행 중... ---
#
# --- 메뉴: '명태회 비빔냉면' 예측 진행 중... ---
#
# --- 메뉴: '문막 복분자 칵테일' 예측 진행 중... ---
#
# --- 메뉴: '봉평메밀 물냉면' 예측 진행 중... ---
#
# --- 메뉴: '생목살 김치찌개' 예측 진행 중... ---
#
# --- 메뉴: '스프라이트' 예측 진행 중... ---
#
# --- 메뉴: '은이버섯 갈비탕' 예측 진행 중... ---
#
# --- 메뉴: '제로콜라' 예측 진행 중... ---
#
# --- 메뉴: '참이슬' 예측 진행 중... ---
#
# --- 메뉴: '처음처럼' 예측 진행 중... ---
#
# --- 메뉴: '카스' 예측 진행 중... ---
#
# --- 메뉴: '콜라' 예측 진행 중... ---
#
# --- 메뉴: '테라' 예측 진행 중... ---
#
# --- 메뉴: '하동 매실 칵테일' 예측 진행 중... ---
#
# --- 메뉴: '한우 떡갈비 정식' 예측 진행 중... ---
#
# --- 메뉴: '한우 미역국 정식' 예측 진행 중... ---
#
# --- 메뉴: '한우 우거지 국밥' 예측 진행 중... ---
#
# --- 메뉴: '한우 차돌박이 된장찌개' 예측 진행 중... ---
#
# --- 메뉴: '황태해장국' 예측 진행 중... ---
#
# 성공적으로 예측이 완료되었습니다. 결과는 'test_predictions_by_date.csv' 파일에 저장되었습니다.

# %% [markdown]
# holt-winters 모델 (라그로타)

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. 데이터 불러오기
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/라그로타_data.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/라그로타_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 2. 고유한 메뉴 목록 추출
unique_menus = test_df['menu'].unique()
print(f"\n총 {len(unique_menus)}개의 메뉴에 대해 예측을 시작합니다.")

# 3. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 시작 ---")

    # 해당 메뉴에 대한 훈련/테스트 데이터 필터링
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    test_menu_df = test_df[test_df['menu'] == menu_item].copy()

    # 결측값 포함 행 제거 (날짜 생성 전)
    train_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)
    test_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)

    # 날짜별 'sum' 값 합산 (중복 날짜 제거)
    train_agg = train_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()
    test_agg = test_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()

    if train_agg.empty or test_agg.empty:
        print(f"'{menu_item}' 메뉴의 데이터가 부족하여 예측을 건너뜁니다.")
        continue

    # 날짜 인덱스 생성
    train_agg['date'] = pd.to_datetime(train_agg[['year', 'month', 'day']])
    train_agg.set_index('date', inplace=True)

    test_agg['date'] = pd.to_datetime(test_agg[['year', 'month', 'day']])
    test_agg.set_index('date', inplace=True)

    # 시계열 데이터 선택
    train_series = train_agg['sum']
    test_series = test_agg['sum']

    # 날짜가 비어있는 경우 일별 빈도(D)로 채우기
    train_series = train_series.asfreq('D')
    test_series = test_series.asfreq('D')

    # Holt-Winters 모델 구현 및 훈련
    model = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_model = model.fit()

    # 예측
    forecast_steps = len(test_series)
    predictions = fitted_model.forecast(steps=forecast_steps)

    # 평가
    results_df = pd.DataFrame({
        'actual': test_series,
        'predicted': predictions
    }).dropna()

    if not results_df.empty:
        actual_values = results_df['actual']
        predictions_filtered = results_df['predicted']

        mse = mean_squared_error(actual_values, predictions_filtered)
        rmse = np.sqrt(mse)

        print(f"  예측값 (상위 5개): \n{predictions_filtered.head()}")
        print(f"\n  실제 테스트 데이터 (상위 5개): \n{actual_values.head()}")
        print(f"\n  MSE (Mean Squared Error): {mse:.2f}")
        print(f"  RMSE (Root Mean Squared Error): {rmse:.2f}")
    else:
        print("  예측과 실제값을 비교할 데이터가 부족하여 평가를 건너뜁니다.")

    print(f"\n--- 메뉴: '{menu_item}' 예측 종료 ---\n")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 25개의 메뉴에 대해 예측을 시작합니다.
#
# --- 메뉴: 'AUS (200g)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.462362
# 2024-06-17   -0.022658
# 2024-06-18    1.791675
# 2024-06-19    1.819386
# 2024-06-20    1.768611
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 5.05
#   RMSE (Root Mean Squared Error): 2.25
#
# --- 메뉴: 'AUS (200g)' 예측 종료 ---
#
#
# --- 메뉴: 'G-Charge(3)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.425447
# 2024-06-17    0.068879
# 2024-06-18    0.279551
# 2024-06-19    0.688187
# 2024-06-20    0.806526
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.09
#   RMSE (Root Mean Squared Error): 1.05
#
# --- 메뉴: 'G-Charge(3)' 예측 종료 ---
#
#
# --- 메뉴: 'Gls.Sileni' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.344505
# 2024-06-17   -0.090088
# 2024-06-18    0.647115
# 2024-06-19    0.633672
# 2024-06-20    0.529133
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2.24
#   RMSE (Root Mean Squared Error): 1.50
#
# --- 메뉴: 'Gls.Sileni' 예측 종료 ---
#
#
# --- 메뉴: 'Gls.미션 서드' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.793320
# 2024-06-17   -0.233715
# 2024-06-18    1.069671
# 2024-06-19    1.214232
# 2024-06-20    1.595464
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    3.0
# 2024-06-17    0.0
# 2024-06-18    2.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 9.27
#   RMSE (Root Mean Squared Error): 3.05
#
# --- 메뉴: 'Gls.미션 서드' 예측 종료 ---
#
#
# --- 메뉴: 'Open Food' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.364059
# 2024-06-17    0.858424
# 2024-06-18    1.252678
# 2024-06-19    1.631648
# 2024-06-20    1.662629
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 27.99
#   RMSE (Root Mean Squared Error): 5.29
#
# --- 메뉴: 'Open Food' 예측 종료 ---
#
#
# --- 메뉴: '그릴드 비프 샐러드' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.876475
# 2024-06-17    1.021154
# 2024-06-18    1.625832
# 2024-06-19    1.665770
# 2024-06-20    1.678907
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    2.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3.75
#   RMSE (Root Mean Squared Error): 1.94
#
# --- 메뉴: '그릴드 비프 샐러드' 예측 종료 ---
#
#
# --- 메뉴: '까르보나라' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.462201
# 2024-06-17    0.086713
# 2024-06-18    1.606897
# 2024-06-19    1.494400
# 2024-06-20    2.131249
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    4.0
# 2024-06-19    1.0
# 2024-06-20    4.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 6.62
#   RMSE (Root Mean Squared Error): 2.57
#
# --- 메뉴: '까르보나라' 예측 종료 ---
#
#
# --- 메뉴: '모둠 해산물 플래터' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.594415
# 2024-06-17    0.173901
# 2024-06-18    0.453473
# 2024-06-19    0.483853
# 2024-06-20    0.505187
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.01
#   RMSE (Root Mean Squared Error): 1.00
#
# --- 메뉴: '모둠 해산물 플래터' 예측 종료 ---
#
#
# --- 메뉴: '미션 서드 카베르네 쉬라' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.421490
# 2024-06-17   -0.025882
# 2024-06-18    0.289912
# 2024-06-19    0.355725
# 2024-06-20    1.158336
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    9.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2.44
#   RMSE (Root Mean Squared Error): 1.56
#
# --- 메뉴: '미션 서드 카베르네 쉬라' 예측 종료 ---
#
#
# --- 메뉴: '버섯 크림 리조또' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.186238
# 2024-06-17    0.590489
# 2024-06-18    2.773290
# 2024-06-19    3.202220
# 2024-06-20    3.104164
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    2.0
# 2024-06-19    1.0
# 2024-06-20    6.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 8.64
#   RMSE (Root Mean Squared Error): 2.94
#
# --- 메뉴: '버섯 크림 리조또' 예측 종료 ---
#
#
# --- 메뉴: '빵 추가 (1인)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.977628
# 2024-06-17   -0.481943
# 2024-06-18    0.330992
# 2024-06-19    0.515989
# 2024-06-20    1.096450
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 7.61
#   RMSE (Root Mean Squared Error): 2.76
#
# --- 메뉴: '빵 추가 (1인)' 예측 종료 ---
#
#
# --- 메뉴: '스프라이트' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.400891
# 2024-06-17   -0.138583
# 2024-06-18   -0.007006
# 2024-06-19   -0.085939
# 2024-06-20    0.519324
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.66
#   RMSE (Root Mean Squared Error): 1.29
#
# --- 메뉴: '스프라이트' 예측 종료 ---
#
#
# --- 메뉴: '시저 샐러드 ' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.725802
# 2024-06-17    0.224044
# 2024-06-18    1.589984
# 2024-06-19    1.607531
# 2024-06-20    1.563051
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    4.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 4.32
#   RMSE (Root Mean Squared Error): 2.08
#
# --- 메뉴: '시저 샐러드 ' 예측 종료 ---
#
#
# --- 메뉴: '아메리카노' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.066743
# 2024-06-17    0.132540
# 2024-06-18    1.000952
# 2024-06-19    1.290420
# 2024-06-20    0.843051
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2.61
#   RMSE (Root Mean Squared Error): 1.61
#
# --- 메뉴: '아메리카노' 예측 종료 ---
#
#
# --- 메뉴: '알리오 에 올리오 ' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.789765
# 2024-06-17    0.089754
# 2024-06-18    1.690659
# 2024-06-19    4.110151
# 2024-06-20    2.758429
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    3.0
# 2024-06-19    2.0
# 2024-06-20    3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 7.75
#   RMSE (Root Mean Squared Error): 2.78
#
# --- 메뉴: '알리오 에 올리오 ' 예측 종료 ---
#
#
# --- 메뉴: '양갈비 (4ps)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.755985
# 2024-06-17    1.743918
# 2024-06-18    3.439612
# 2024-06-19    2.698642
# 2024-06-20    2.862391
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    4.0
# 2024-06-17    0.0
# 2024-06-18    2.0
# 2024-06-19    0.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 14.61
#   RMSE (Root Mean Squared Error): 3.82
#
# --- 메뉴: '양갈비 (4ps)' 예측 종료 ---
#
#
# --- 메뉴: '자몽리치에이드' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.829103
# 2024-06-17   -0.091919
# 2024-06-18    0.355287
# 2024-06-19    0.552769
# 2024-06-20    0.631854
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2.59
#   RMSE (Root Mean Squared Error): 1.61
#
# --- 메뉴: '자몽리치에이드' 예측 종료 ---
#
#
# --- 메뉴: '제로콜라' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.842581
# 2024-06-17   -0.144260
# 2024-06-18    0.316306
# 2024-06-19    0.382058
# 2024-06-20    0.500497
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3.77
#   RMSE (Root Mean Squared Error): 1.94
#
# --- 메뉴: '제로콜라' 예측 종료 ---
#
#
# --- 메뉴: '카스' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.942105
# 2024-06-17    0.376078
# 2024-06-18    0.981574
# 2024-06-19    0.639179
# 2024-06-20    0.889419
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    4.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 4.41
#   RMSE (Root Mean Squared Error): 2.10
#
# --- 메뉴: '카스' 예측 종료 ---
#
#
# --- 메뉴: '콜라' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.629395
# 2024-06-17    0.247812
# 2024-06-18    1.103075
# 2024-06-19    0.629393
# 2024-06-20    1.405709
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    8.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 5.50
#   RMSE (Root Mean Squared Error): 2.35
#
# --- 메뉴: '콜라' 예측 종료 ---
#
#
# --- 메뉴: '하이네켄(생)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.167836
# 2024-06-17    0.469753
# 2024-06-18    1.403514
# 2024-06-19    1.612069
# 2024-06-20    1.984028
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    5.0
# 2024-06-19    2.0
# 2024-06-20    2.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 7.39
#   RMSE (Root Mean Squared Error): 2.72
#
# --- 메뉴: '하이네켄(생)' 예측 종료 ---
#
#
# --- 메뉴: '한우 (200g)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.274481
# 2024-06-17    0.255147
# 2024-06-18    0.646787
# 2024-06-19    0.757877
# 2024-06-20    0.793135
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    3.0
# 2024-06-19    0.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 5.10
#   RMSE (Root Mean Squared Error): 2.26
#
# --- 메뉴: '한우 (200g)' 예측 종료 ---
#
#
# --- 메뉴: '해산물 토마토 리조또' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.321972
# 2024-06-17   -0.388487
# 2024-06-18   -0.072493
# 2024-06-19   -0.170775
# 2024-06-20   -0.017170
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    0.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 9.59
#   RMSE (Root Mean Squared Error): 3.10
#
# --- 메뉴: '해산물 토마토 리조또' 예측 종료 ---
#
#
# --- 메뉴: '해산물 토마토 스튜 파스타' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.755884
# 2024-06-17    1.522166
# 2024-06-18    3.381993
# 2024-06-19    3.218903
# 2024-06-20    3.702045
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 10.16
#   RMSE (Root Mean Squared Error): 3.19
#
# --- 메뉴: '해산물 토마토 스튜 파스타' 예측 종료 ---
#
#
# --- 메뉴: '해산물 토마토 스파게티' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    5.504454
# 2024-06-17    0.412376
# 2024-06-18    3.491224
# 2024-06-19    4.017593
# 2024-06-20    4.109780
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    3.0
# 2024-06-17    0.0
# 2024-06-18    2.0
# 2024-06-19    2.0
# 2024-06-20    3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 8.34
#   RMSE (Root Mean Squared Error): 2.89
#
# --- 메뉴: '해산물 토마토 스파게티' 예측 종료 ---

# %% [markdown]
# 담하 영업장의 submission 파일 생성

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np
import warnings
from datetime import timedelta

# statsmodels 경고 무시
warnings.filterwarnings("ignore")

# 1. 데이터 불러오기 및 전처리
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/라그로타_data.csv')
    test_df_original = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/라그로타_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 날짜/시간 인덱스 생성
train_df['date'] = pd.to_datetime(train_df[['year', 'month', 'day']])
test_df_original['date'] = pd.to_datetime(test_df_original[['year', 'month', 'day']])

# 결측값 포함 행 제거
train_df.dropna(subset=['date', 'sum'], inplace=True)
test_df_original.dropna(subset=['date', 'sum'], inplace=True)

# 2. 예측 대상 날짜들 찾기 (모든 메뉴에 대해 공통)
# 테스트 데이터의 전체 날짜 범위
full_test_date_range = pd.date_range(
    start=test_df_original['date'].min(),
    end=test_df_original['date'].max(),
    freq='D'
)

# 테스트 데이터에 실제 값이 존재하는 날짜
dates_with_data = pd.to_datetime(test_df_original['date'].unique())

# 전체 날짜 범위에서 실제 데이터가 있는 날짜를 제외하여 빈 기간 식별
missing_dates = full_test_date_range.difference(dates_with_data)

# 마지막 7일 기간 추가 (테스트 데이터 마지막 날 다음 날부터)
last_test_date = test_df_original['date'].max()
final_week_dates = pd.date_range(
    start=last_test_date + timedelta(days=1),
    periods=7,
    freq='D'
)

# 예측할 날짜 전체 리스트 생성
forecast_dates = missing_dates.append(final_week_dates).sort_values()

# 예측할 날짜 목록 출력
print(f"\n총 {len(forecast_dates)}개의 날짜에 대해 예측을 수행합니다.")
print("예측 날짜 목록:")
print(forecast_dates)

# 3. 고유한 메뉴 목록 추출 및 예측
unique_menus = test_df_original['menu'].unique()
predictions_dict = {}

# 4. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 진행 중... ---")

    # 해당 메뉴에 대한 훈련 데이터 필터링 및 합산
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    train_series = train_menu_df.groupby('date')['sum'].sum().asfreq('D')

    if train_series.empty:
        predictions_dict[menu_item] = np.zeros(len(forecast_dates))
        print(f"  데이터 부족으로 '{menu_item}' 예측값을 0으로 처리합니다.")
        continue

    # Holt-Winters 모델 훈련
    model_hw = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_hw = model_hw.fit()

    # 예측 수행
    menu_predictions_series = fitted_hw.predict(
        start=forecast_dates.min(),
        end=forecast_dates.max()
    )

    # 예측값을 빈 날짜에 맞게 필터링
    final_predictions_for_menu = menu_predictions_series.reindex(forecast_dates)

    # 예측값 저장
    predictions_dict[menu_item] = final_predictions_for_menu.values

# 5. 예측값으로 최종 데이터프레임 생성
final_predictions_df = pd.DataFrame(predictions_dict, index=forecast_dates)

# 열 라벨(column labels) 생성
column_labels = [f"라그로타_{menu}" for menu in unique_menus]
final_predictions_df.columns = column_labels

# 6. 예측 파일로 저장
file_name = 'test_predictions_by_date.csv'
final_predictions_df.to_csv(file_name, encoding='utf-8-sig', index=True)

print(f"\n성공적으로 예측이 완료되었습니다. 결과는 '{file_name}' 파일에 저장되었습니다.")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 70개의 날짜에 대해 예측을 수행합니다.
# 예측 날짜 목록:
# DatetimeIndex(['2024-07-14', '2024-07-15', '2024-07-16', '2024-07-17',
#                '2024-07-18', '2024-07-19', '2024-07-20', '2024-08-18',
#                '2024-08-19', '2024-08-20', '2024-08-21', '2024-08-22',
#                '2024-08-23', '2024-08-24', '2024-09-22', '2024-09-23',
#                '2024-09-24', '2024-09-25', '2024-09-26', '2024-09-27',
#                '2024-09-28', '2024-10-27', '2024-10-28', '2024-10-29',
#                '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-02',
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2025-01-05',
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-09',
#                '2025-01-10', '2025-01-11', '2025-02-09', '2025-02-10',
#                '2025-02-11', '2025-02-12', '2025-02-13', '2025-02-14',
#                '2025-02-15', '2025-03-16', '2025-03-17', '2025-03-18',
#                '2025-03-19', '2025-03-20', '2025-03-21', '2025-03-22',
#                '2025-04-20', '2025-04-21', '2025-04-22', '2025-04-23',
#                '2025-04-24', '2025-04-25', '2025-04-26', '2025-05-25',
#                '2025-05-26', '2025-05-27', '2025-05-28', '2025-05-29',
#                '2025-05-30', '2025-05-31'],
#               dtype='datetime64[ns]', freq=None)
#
# --- 메뉴: 'AUS (200g)' 예측 진행 중... ---
#
# --- 메뉴: 'G-Charge(3)' 예측 진행 중... ---
#
# --- 메뉴: 'Gls.Sileni' 예측 진행 중... ---
#
# --- 메뉴: 'Gls.미션 서드' 예측 진행 중... ---
#
# --- 메뉴: 'Open Food' 예측 진행 중... ---
#
# --- 메뉴: '그릴드 비프 샐러드' 예측 진행 중... ---
#
# --- 메뉴: '까르보나라' 예측 진행 중... ---
#
# --- 메뉴: '모둠 해산물 플래터' 예측 진행 중... ---
#
# --- 메뉴: '미션 서드 카베르네 쉬라' 예측 진행 중... ---
#
# --- 메뉴: '버섯 크림 리조또' 예측 진행 중... ---
#
# --- 메뉴: '빵 추가 (1인)' 예측 진행 중... ---
#
# --- 메뉴: '스프라이트' 예측 진행 중... ---
#
# --- 메뉴: '시저 샐러드 ' 예측 진행 중... ---
#
# --- 메뉴: '아메리카노' 예측 진행 중... ---
#
# --- 메뉴: '알리오 에 올리오 ' 예측 진행 중... ---
#
# --- 메뉴: '양갈비 (4ps)' 예측 진행 중... ---
#
# --- 메뉴: '자몽리치에이드' 예측 진행 중... ---
#
# --- 메뉴: '제로콜라' 예측 진행 중... ---
#
# --- 메뉴: '카스' 예측 진행 중... ---
#
# --- 메뉴: '콜라' 예측 진행 중... ---
#
# --- 메뉴: '하이네켄(생)' 예측 진행 중... ---
#
# --- 메뉴: '한우 (200g)' 예측 진행 중... ---
#
# --- 메뉴: '해산물 토마토 리조또' 예측 진행 중... ---
#
# --- 메뉴: '해산물 토마토 스튜 파스타' 예측 진행 중... ---
#
# --- 메뉴: '해산물 토마토 스파게티' 예측 진행 중... ---
#
# 성공적으로 예측이 완료되었습니다. 결과는 'test_predictions_by_date.csv' 파일에 저장되었습니다.

# %% [markdown]
# holt-winters 모델 (미라시아)

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. 데이터 불러오기
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/미라시아_data.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/미라시아_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 2. 고유한 메뉴 목록 추출
unique_menus = test_df['menu'].unique()
print(f"\n총 {len(unique_menus)}개의 메뉴에 대해 예측을 시작합니다.")

# 3. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 시작 ---")

    # 해당 메뉴에 대한 훈련/테스트 데이터 필터링
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    test_menu_df = test_df[test_df['menu'] == menu_item].copy()

    # 결측값 포함 행 제거 (날짜 생성 전)
    train_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)
    test_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)

    # 날짜별 'sum' 값 합산 (중복 날짜 제거)
    train_agg = train_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()
    test_agg = test_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()

    if train_agg.empty or test_agg.empty:
        print(f"'{menu_item}' 메뉴의 데이터가 부족하여 예측을 건너뜁니다.")
        continue

    # 날짜 인덱스 생성
    train_agg['date'] = pd.to_datetime(train_agg[['year', 'month', 'day']])
    train_agg.set_index('date', inplace=True)

    test_agg['date'] = pd.to_datetime(test_agg[['year', 'month', 'day']])
    test_agg.set_index('date', inplace=True)

    # 시계열 데이터 선택
    train_series = train_agg['sum']
    test_series = test_agg['sum']

    # 날짜가 비어있는 경우 일별 빈도(D)로 채우기
    train_series = train_series.asfreq('D')
    test_series = test_series.asfreq('D')

    # Holt-Winters 모델 구현 및 훈련
    model = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_model = model.fit()

    # 예측
    forecast_steps = len(test_series)
    predictions = fitted_model.forecast(steps=forecast_steps)

    # 평가
    results_df = pd.DataFrame({
        'actual': test_series,
        'predicted': predictions
    }).dropna()

    if not results_df.empty:
        actual_values = results_df['actual']
        predictions_filtered = results_df['predicted']

        mse = mean_squared_error(actual_values, predictions_filtered)
        rmse = np.sqrt(mse)

        print(f"  예측값 (상위 5개): \n{predictions_filtered.head()}")
        print(f"\n  실제 테스트 데이터 (상위 5개): \n{actual_values.head()}")
        print(f"\n  MSE (Mean Squared Error): {mse:.2f}")
        print(f"  RMSE (Root Mean Squared Error): {rmse:.2f}")
    else:
        print("  예측과 실제값을 비교할 데이터가 부족하여 평가를 건너뜁니다.")

    print(f"\n--- 메뉴: '{menu_item}' 예측 종료 ---\n")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 31개의 메뉴에 대해 예측을 시작합니다.
#
# --- 메뉴: '(단체)브런치주중 36,000' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16     3.767847
# 2024-06-17    17.451224
# 2024-06-18    47.003344
# 2024-06-19    31.634874
# 2024-06-20    49.953013
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16      0.0
# 2024-06-17      0.0
# 2024-06-18     25.0
# 2024-06-19     32.0
# 2024-06-20    161.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2278.13
#   RMSE (Root Mean Squared Error): 47.73
#
# --- 메뉴: '(단체)브런치주중 36,000' 예측 종료 ---
#
#
# --- 메뉴: '(오븐) 하와이안 쉬림프 피자' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.674469
# 2024-06-17    0.543125
# 2024-06-18    0.556196
# 2024-06-19    0.358633
# 2024-06-20    0.595483
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.94
#   RMSE (Root Mean Squared Error): 1.39
#
# --- 메뉴: '(오븐) 하와이안 쉬림프 피자' 예측 종료 ---
#
#
# --- 메뉴: '(화덕) 불고기 페퍼로니 반반피자' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.230027
# 2024-06-17    1.124899
# 2024-06-18    0.716969
# 2024-06-19    0.387876
# 2024-06-20    0.861694
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 11.07
#   RMSE (Root Mean Squared Error): 3.33
#
# --- 메뉴: '(화덕) 불고기 페퍼로니 반반피자' 예측 종료 ---
#
#
# --- 메뉴: 'BBQ Platter' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    4.795332
# 2024-06-17    1.598136
# 2024-06-18    1.071954
# 2024-06-19    0.269268
# 2024-06-20    1.098307
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    3.0
# 2024-06-17    3.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 53.16
#   RMSE (Root Mean Squared Error): 7.29
#
# --- 메뉴: 'BBQ Platter' 예측 종료 ---
#
#
# --- 메뉴: 'BBQ 고기추가' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.862112
# 2024-06-17    0.677895
# 2024-06-18    0.388408
# 2024-06-19    0.151617
# 2024-06-20    0.559516
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.66
#   RMSE (Root Mean Squared Error): 1.29
#
# --- 메뉴: 'BBQ 고기추가' 예측 종료 ---
#
#
# --- 메뉴: '공깃밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.840230
# 2024-06-17    0.190803
# 2024-06-18    0.730097
# 2024-06-19    0.754316
# 2024-06-20    0.417813
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 6.99
#   RMSE (Root Mean Squared Error): 2.64
#
# --- 메뉴: '공깃밥' 예측 종료 ---
#
#
# --- 메뉴: '글라스와인 (레드)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.313574
# 2024-06-17    0.260929
# 2024-06-18    0.076715
# 2024-06-19    0.050394
# 2024-06-20    0.155654
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    2.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.39
#   RMSE (Root Mean Squared Error): 1.18
#
# --- 메뉴: '글라스와인 (레드)' 예측 종료 ---
#
#
# --- 메뉴: '레인보우칵테일(알코올)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.779405
# 2024-06-17    0.450464
# 2024-06-18    0.384667
# 2024-06-19    0.200463
# 2024-06-20    0.450458
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.65
#   RMSE (Root Mean Squared Error): 0.81
#
# --- 메뉴: '레인보우칵테일(알코올)' 예측 종료 ---
#
#
# --- 메뉴: '미라시아 브런치 (패키지)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    14.195650
# 2024-06-17    10.312733
# 2024-06-18    14.390539
# 2024-06-19    18.683023
# 2024-06-20    20.028440
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     6.0
# 2024-06-17     4.0
# 2024-06-18     4.0
# 2024-06-19    10.0
# 2024-06-20     2.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 376.34
#   RMSE (Root Mean Squared Error): 19.40
#
# --- 메뉴: '미라시아 브런치 (패키지)' 예측 종료 ---
#
#
# --- 메뉴: '버드와이저(무제한)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.084420
# 2024-06-17    0.975381
# 2024-06-18    1.530808
# 2024-06-19    0.901220
# 2024-06-20    1.166714
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 28.74
#   RMSE (Root Mean Squared Error): 5.36
#
# --- 메뉴: '버드와이저(무제한)' 예측 종료 ---
#
#
# --- 메뉴: '보일링 랍스타 플래터' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.708572
# 2024-06-17    0.498088
# 2024-06-18    0.458647
# 2024-06-19    0.471719
# 2024-06-20    0.590145
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3.69
#   RMSE (Root Mean Squared Error): 1.92
#
# --- 메뉴: '보일링 랍스타 플래터' 예측 종료 ---
#
#
# --- 메뉴: '보일링 랍스타 플래터(덜매운맛)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.611266
# 2024-06-17    0.427075
# 2024-06-18    0.348094
# 2024-06-19    0.584902
# 2024-06-20    0.400701
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.23
#   RMSE (Root Mean Squared Error): 1.11
#
# --- 메뉴: '보일링 랍스타 플래터(덜매운맛)' 예측 종료 ---
#
#
# --- 메뉴: '브런치 2인 패키지 ' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.492815
# 2024-06-17    3.788847
# 2024-06-18    1.929983
# 2024-06-19    2.442007
# 2024-06-20    4.616347
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    6.0
# 2024-06-17    3.0
# 2024-06-18    1.0
# 2024-06-19    0.0
# 2024-06-20    2.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 48.03
#   RMSE (Root Mean Squared Error): 6.93
#
# --- 메뉴: '브런치 2인 패키지 ' 예측 종료 ---
#
#
# --- 메뉴: '브런치 4인 패키지 ' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.116802
# 2024-06-17    0.419421
# 2024-06-18    0.195797
# 2024-06-19    0.077347
# 2024-06-20    0.143138
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.38
#   RMSE (Root Mean Squared Error): 0.62
#
# --- 메뉴: '브런치 4인 패키지 ' 예측 종료 ---
#
#
# --- 메뉴: '브런치(대인) 주말' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    195.182345
# 2024-06-17      1.719779
# 2024-06-18     -8.997399
# 2024-06-19      9.794663
# 2024-06-20     18.908569
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    187.0
# 2024-06-17      0.0
# 2024-06-18      0.0
# 2024-06-19      0.0
# 2024-06-20      2.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2979.12
#   RMSE (Root Mean Squared Error): 54.58
#
# --- 메뉴: '브런치(대인) 주말' 예측 종료 ---
#
#
# --- 메뉴: '브런치(대인) 주중' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -11.903601
# 2024-06-17    54.226846
# 2024-06-18    39.734416
# 2024-06-19    40.645200
# 2024-06-20    33.903346
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     0.0
# 2024-06-17    59.0
# 2024-06-18    19.0
# 2024-06-19    25.0
# 2024-06-20    21.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1624.94
#   RMSE (Root Mean Squared Error): 40.31
#
# --- 메뉴: '브런치(대인) 주중' 예측 종료 ---
#
#
# --- 메뉴: '브런치(어린이)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    33.542354
# 2024-06-17    -1.477601
# 2024-06-18    -7.870515
# 2024-06-19    -1.189641
# 2024-06-20     6.481598
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    49.0
# 2024-06-17     9.0
# 2024-06-18     1.0
# 2024-06-19     0.0
# 2024-06-20     7.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 601.65
#   RMSE (Root Mean Squared Error): 24.53
#
# --- 메뉴: '브런치(어린이)' 예측 종료 ---
#
#
# --- 메뉴: '쉬림프 투움바 파스타' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.595957
# 2024-06-17    0.989340
# 2024-06-18    0.778682
# 2024-06-19    0.937655
# 2024-06-20    1.194813
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    2.0
# 2024-06-18    1.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 9.11
#   RMSE (Root Mean Squared Error): 3.02
#
# --- 메뉴: '쉬림프 투움바 파스타' 예측 종료 ---
#
#
# --- 메뉴: '스텔라(무제한)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.326946
# 2024-06-17    1.775050
# 2024-06-18    1.852210
# 2024-06-19    1.550441
# 2024-06-20    2.041107
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 14.68
#   RMSE (Root Mean Squared Error): 3.83
#
# --- 메뉴: '스텔라(무제한)' 예측 종료 ---
#
#
# --- 메뉴: '스프라이트' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.733072
# 2024-06-17    0.496247
# 2024-06-18    0.364661
# 2024-06-19    0.391014
# 2024-06-20    0.588370
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2.43
#   RMSE (Root Mean Squared Error): 1.56
#
# --- 메뉴: '스프라이트' 예측 종료 ---
#
#
# --- 메뉴: '애플망고 에이드' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.914009
# 2024-06-17    0.650829
# 2024-06-18    1.019248
# 2024-06-19    0.400842
# 2024-06-20    0.729807
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    4.0
# 2024-06-17    1.0
# 2024-06-18    0.0
# 2024-06-19    2.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 16.31
#   RMSE (Root Mean Squared Error): 4.04
#
# --- 메뉴: '애플망고 에이드' 예측 종료 ---
#
#
# --- 메뉴: '얼그레이 하이볼' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.462648
# 2024-06-17    0.173180
# 2024-06-18    0.133701
# 2024-06-19   -0.155773
# 2024-06-20    0.041600
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.82
#   RMSE (Root Mean Squared Error): 0.91
#
# --- 메뉴: '얼그레이 하이볼' 예측 종료 ---
#
#
# --- 메뉴: '오븐구이 윙과 킬바사소세지' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.939664
# 2024-06-17    1.202858
# 2024-06-18    0.834410
# 2024-06-19    0.465996
# 2024-06-20    0.637043
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    2.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2.71
#   RMSE (Root Mean Squared Error): 1.65
#
# --- 메뉴: '오븐구이 윙과 킬바사소세지' 예측 종료 ---
#
#
# --- 메뉴: '유자 하이볼' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.509809
# 2024-06-17    0.312557
# 2024-06-18    0.470360
# 2024-06-19    0.365144
# 2024-06-20    0.444277
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.88
#   RMSE (Root Mean Squared Error): 0.94
#
# --- 메뉴: '유자 하이볼' 예측 종료 ---
#
#
# --- 메뉴: '잭 애플 토닉' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.502595
# 2024-06-17    0.344650
# 2024-06-18    0.318439
# 2024-06-19    0.410453
# 2024-06-20    0.384200
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.13
#   RMSE (Root Mean Squared Error): 1.06
#
# --- 메뉴: '잭 애플 토닉' 예측 종료 ---
#
#
# --- 메뉴: '칠리 치즈 프라이' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.282216
# 2024-06-17    0.282230
# 2024-06-18    0.387502
# 2024-06-19    0.124328
# 2024-06-20    0.084865
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.12
#   RMSE (Root Mean Squared Error): 1.06
#
# --- 메뉴: '칠리 치즈 프라이' 예측 종료 ---
#
#
# --- 메뉴: '코카콜라' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.693226
# 2024-06-17    1.061615
# 2024-06-18    0.680014
# 2024-06-19    0.561600
# 2024-06-20    1.008992
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    1.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 4.18
#   RMSE (Root Mean Squared Error): 2.04
#
# --- 메뉴: '코카콜라' 예측 종료 ---
#
#
# --- 메뉴: '코카콜라(제로)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.767118
# 2024-06-17    0.385507
# 2024-06-18    0.411837
# 2024-06-19    0.425011
# 2024-06-20    0.582919
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3.11
#   RMSE (Root Mean Squared Error): 1.76
#
# --- 메뉴: '코카콜라(제로)' 예측 종료 ---
#
#
# --- 메뉴: '콥 샐러드' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.484643
# 2024-06-17   -0.076523
# 2024-06-18   -0.246808
# 2024-06-19    0.119228
# 2024-06-20    0.823471
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    3.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 6.82
#   RMSE (Root Mean Squared Error): 2.61
#
# --- 메뉴: '콥 샐러드' 예측 종료 ---
#
#
# --- 메뉴: '파스타면 추가(150g)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.866251
# 2024-06-17    0.353099
# 2024-06-18    0.353029
# 2024-06-19    0.629369
# 2024-06-20    0.431865
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2.69
#   RMSE (Root Mean Squared Error): 1.64
#
# --- 메뉴: '파스타면 추가(150g)' 예측 종료 ---
#
#
# --- 메뉴: '핑크레몬에이드' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.318710
# 2024-06-17    0.213450
# 2024-06-18   -0.102352
# 2024-06-19   -0.299733
# 2024-06-20    0.081863
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.98
#   RMSE (Root Mean Squared Error): 0.99
#
# --- 메뉴: '핑크레몬에이드' 예측 종료 ---

# %% [markdown]
# 미라시아 영업장의 submission 파일 생성

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np
import warnings
from datetime import timedelta

# statsmodels 경고 무시
warnings.filterwarnings("ignore")

# 1. 데이터 불러오기 및 전처리
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/미라시아_data.csv')
    test_df_original = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/미라시아_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 날짜/시간 인덱스 생성
train_df['date'] = pd.to_datetime(train_df[['year', 'month', 'day']])
test_df_original['date'] = pd.to_datetime(test_df_original[['year', 'month', 'day']])

# 결측값 포함 행 제거
train_df.dropna(subset=['date', 'sum'], inplace=True)
test_df_original.dropna(subset=['date', 'sum'], inplace=True)

# 2. 예측 대상 날짜들 찾기 (모든 메뉴에 대해 공통)
# 테스트 데이터의 전체 날짜 범위
full_test_date_range = pd.date_range(
    start=test_df_original['date'].min(),
    end=test_df_original['date'].max(),
    freq='D'
)

# 테스트 데이터에 실제 값이 존재하는 날짜
dates_with_data = pd.to_datetime(test_df_original['date'].unique())

# 전체 날짜 범위에서 실제 데이터가 있는 날짜를 제외하여 빈 기간 식별
missing_dates = full_test_date_range.difference(dates_with_data)

# 마지막 7일 기간 추가 (테스트 데이터 마지막 날 다음 날부터)
last_test_date = test_df_original['date'].max()
final_week_dates = pd.date_range(
    start=last_test_date + timedelta(days=1),
    periods=7,
    freq='D'
)

# 예측할 날짜 전체 리스트 생성
forecast_dates = missing_dates.append(final_week_dates).sort_values()

# 예측할 날짜 목록 출력
print(f"\n총 {len(forecast_dates)}개의 날짜에 대해 예측을 수행합니다.")
print("예측 날짜 목록:")
print(forecast_dates)

# 3. 고유한 메뉴 목록 추출 및 예측
unique_menus = test_df_original['menu'].unique()
predictions_dict = {}

# 4. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 진행 중... ---")

    # 해당 메뉴에 대한 훈련 데이터 필터링 및 합산
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    train_series = train_menu_df.groupby('date')['sum'].sum().asfreq('D')

    if train_series.empty:
        predictions_dict[menu_item] = np.zeros(len(forecast_dates))
        print(f"  데이터 부족으로 '{menu_item}' 예측값을 0으로 처리합니다.")
        continue

    # Holt-Winters 모델 훈련
    model_hw = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_hw = model_hw.fit()

    # 예측 수행
    menu_predictions_series = fitted_hw.predict(
        start=forecast_dates.min(),
        end=forecast_dates.max()
    )

    # 예측값을 빈 날짜에 맞게 필터링
    final_predictions_for_menu = menu_predictions_series.reindex(forecast_dates)

    # 예측값 저장
    predictions_dict[menu_item] = final_predictions_for_menu.values

# 5. 예측값으로 최종 데이터프레임 생성
final_predictions_df = pd.DataFrame(predictions_dict, index=forecast_dates)

# 열 라벨(column labels) 생성
column_labels = [f"미라시아_{menu}" for menu in unique_menus]
final_predictions_df.columns = column_labels

# 6. 예측 파일로 저장
file_name = 'test_predictions_by_date.csv'
final_predictions_df.to_csv(file_name, encoding='utf-8-sig', index=True)

print(f"\n성공적으로 예측이 완료되었습니다. 결과는 '{file_name}' 파일에 저장되었습니다.")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 70개의 날짜에 대해 예측을 수행합니다.
# 예측 날짜 목록:
# DatetimeIndex(['2024-07-14', '2024-07-15', '2024-07-16', '2024-07-17',
#                '2024-07-18', '2024-07-19', '2024-07-20', '2024-08-18',
#                '2024-08-19', '2024-08-20', '2024-08-21', '2024-08-22',
#                '2024-08-23', '2024-08-24', '2024-09-22', '2024-09-23',
#                '2024-09-24', '2024-09-25', '2024-09-26', '2024-09-27',
#                '2024-09-28', '2024-10-27', '2024-10-28', '2024-10-29',
#                '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-02',
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2025-01-05',
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-09',
#                '2025-01-10', '2025-01-11', '2025-02-09', '2025-02-10',
#                '2025-02-11', '2025-02-12', '2025-02-13', '2025-02-14',
#                '2025-02-15', '2025-03-16', '2025-03-17', '2025-03-18',
#                '2025-03-19', '2025-03-20', '2025-03-21', '2025-03-22',
#                '2025-04-20', '2025-04-21', '2025-04-22', '2025-04-23',
#                '2025-04-24', '2025-04-25', '2025-04-26', '2025-05-25',
#                '2025-05-26', '2025-05-27', '2025-05-28', '2025-05-29',
#                '2025-05-30', '2025-05-31'],
#               dtype='datetime64[ns]', freq=None)
#
# --- 메뉴: '(단체)브런치주중 36,000' 예측 진행 중... ---
#
# --- 메뉴: '(오븐) 하와이안 쉬림프 피자' 예측 진행 중... ---
#
# --- 메뉴: '(화덕) 불고기 페퍼로니 반반피자' 예측 진행 중... ---
#
# --- 메뉴: 'BBQ Platter' 예측 진행 중... ---
#
# --- 메뉴: 'BBQ 고기추가' 예측 진행 중... ---
#
# --- 메뉴: '공깃밥' 예측 진행 중... ---
#
# --- 메뉴: '글라스와인 (레드)' 예측 진행 중... ---
#
# --- 메뉴: '레인보우칵테일(알코올)' 예측 진행 중... ---
#
# --- 메뉴: '미라시아 브런치 (패키지)' 예측 진행 중... ---
#
# --- 메뉴: '버드와이저(무제한)' 예측 진행 중... ---
#
# --- 메뉴: '보일링 랍스타 플래터' 예측 진행 중... ---
#
# --- 메뉴: '보일링 랍스타 플래터(덜매운맛)' 예측 진행 중... ---
#
# --- 메뉴: '브런치 2인 패키지 ' 예측 진행 중... ---
#
# --- 메뉴: '브런치 4인 패키지 ' 예측 진행 중... ---
#
# --- 메뉴: '브런치(대인) 주말' 예측 진행 중... ---
#
# --- 메뉴: '브런치(대인) 주중' 예측 진행 중... ---
#
# --- 메뉴: '브런치(어린이)' 예측 진행 중... ---
#
# --- 메뉴: '쉬림프 투움바 파스타' 예측 진행 중... ---
#
# --- 메뉴: '스텔라(무제한)' 예측 진행 중... ---
#
# --- 메뉴: '스프라이트' 예측 진행 중... ---
#
# --- 메뉴: '애플망고 에이드' 예측 진행 중... ---
#
# --- 메뉴: '얼그레이 하이볼' 예측 진행 중... ---
#
# --- 메뉴: '오븐구이 윙과 킬바사소세지' 예측 진행 중... ---
#
# --- 메뉴: '유자 하이볼' 예측 진행 중... ---
#
# --- 메뉴: '잭 애플 토닉' 예측 진행 중... ---
#
# --- 메뉴: '칠리 치즈 프라이' 예측 진행 중... ---
#
# --- 메뉴: '코카콜라' 예측 진행 중... ---
#
# --- 메뉴: '코카콜라(제로)' 예측 진행 중... ---
#
# --- 메뉴: '콥 샐러드' 예측 진행 중... ---
#
# --- 메뉴: '파스타면 추가(150g)' 예측 진행 중... ---
#
# --- 메뉴: '핑크레몬에이드' 예측 진행 중... ---
#
# 성공적으로 예측이 완료되었습니다. 결과는 'test_predictions_by_date.csv' 파일에 저장되었습니다.

# %% [markdown]
# holt-winters 모델 (연회장)

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. 데이터 불러오기
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/연회장_data.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/연회장_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 2. 고유한 메뉴 목록 추출
unique_menus = test_df['menu'].unique()
print(f"\n총 {len(unique_menus)}개의 메뉴에 대해 예측을 시작합니다.")

# 3. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 시작 ---")

    # 해당 메뉴에 대한 훈련/테스트 데이터 필터링
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    test_menu_df = test_df[test_df['menu'] == menu_item].copy()

    # 결측값 포함 행 제거 (날짜 생성 전)
    train_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)
    test_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)

    # 날짜별 'sum' 값 합산 (중복 날짜 제거)
    train_agg = train_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()
    test_agg = test_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()

    if train_agg.empty or test_agg.empty:
        print(f"'{menu_item}' 메뉴의 데이터가 부족하여 예측을 건너뜁니다.")
        continue

    # 날짜 인덱스 생성
    train_agg['date'] = pd.to_datetime(train_agg[['year', 'month', 'day']])
    train_agg.set_index('date', inplace=True)

    test_agg['date'] = pd.to_datetime(test_agg[['year', 'month', 'day']])
    test_agg.set_index('date', inplace=True)

    # 시계열 데이터 선택
    train_series = train_agg['sum']
    test_series = test_agg['sum']

    # 날짜가 비어있는 경우 일별 빈도(D)로 채우기
    train_series = train_series.asfreq('D')
    test_series = test_series.asfreq('D')

    # Holt-Winters 모델 구현 및 훈련
    model = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_model = model.fit()

    # 예측
    forecast_steps = len(test_series)
    predictions = fitted_model.forecast(steps=forecast_steps)

    # 평가
    results_df = pd.DataFrame({
        'actual': test_series,
        'predicted': predictions
    }).dropna()

    if not results_df.empty:
        actual_values = results_df['actual']
        predictions_filtered = results_df['predicted']

        mse = mean_squared_error(actual_values, predictions_filtered)
        rmse = np.sqrt(mse)

        print(f"  예측값 (상위 5개): \n{predictions_filtered.head()}")
        print(f"\n  실제 테스트 데이터 (상위 5개): \n{actual_values.head()}")
        print(f"\n  MSE (Mean Squared Error): {mse:.2f}")
        print(f"  RMSE (Root Mean Squared Error): {rmse:.2f}")
    else:
        print("  예측과 실제값을 비교할 데이터가 부족하여 평가를 건너뜁니다.")

    print(f"\n--- 메뉴: '{menu_item}' 예측 종료 ---\n")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 23개의 메뉴에 대해 예측을 시작합니다.
#
# --- 메뉴: 'Cass Beer' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    -3.636010
# 2024-06-17     9.337765
# 2024-06-18    18.259328
# 2024-06-19    10.614613
# 2024-06-20    36.063030
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16      0.0
# 2024-06-17      0.0
# 2024-06-18      0.0
# 2024-06-19      0.0
# 2024-06-20    136.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1545.95
#   RMSE (Root Mean Squared Error): 39.32
#
# --- 메뉴: 'Cass Beer' 예측 종료 ---
#
#
# --- 메뉴: 'Conference L1' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.059432
# 2024-06-17    0.230248
# 2024-06-18    0.308824
# 2024-06-19    0.295780
# 2024-06-20    0.546229
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.23
#   RMSE (Root Mean Squared Error): 0.48
#
# --- 메뉴: 'Conference L1' 예측 종료 ---
#
#
# --- 메뉴: 'Conference L2' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.210361
# 2024-06-17    0.460347
# 2024-06-18    0.407724
# 2024-06-19    0.486691
# 2024-06-20    0.841944
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.32
#   RMSE (Root Mean Squared Error): 0.57
#
# --- 메뉴: 'Conference L2' 예측 종료 ---
#
#
# --- 메뉴: 'Conference L3' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.067130
# 2024-06-17    0.117077
# 2024-06-18    0.274974
# 2024-06-19    0.261811
# 2024-06-20    0.551287
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    1.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.18
#   RMSE (Root Mean Squared Error): 0.42
#
# --- 메뉴: 'Conference L3' 예측 종료 ---
#
#
# --- 메뉴: 'Conference M1' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.016495
# 2024-06-17    0.199573
# 2024-06-18    0.261785
# 2024-06-19    0.375481
# 2024-06-20    0.477535
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    1.0
# 2024-06-18    1.0
# 2024-06-19    1.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.22
#   RMSE (Root Mean Squared Error): 0.47
#
# --- 메뉴: 'Conference M1' 예측 종료 ---
#
#
# --- 메뉴: 'Conference M8' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.193084
# 2024-06-17    0.364143
# 2024-06-18    0.377305
# 2024-06-19    0.416777
# 2024-06-20    0.666779
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.26
#   RMSE (Root Mean Squared Error): 0.51
#
# --- 메뉴: 'Conference M8' 예측 종료 ---
#
#
# --- 메뉴: 'Conference M9' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.092804
# 2024-06-17    0.144038
# 2024-06-18    0.196671
# 2024-06-19    0.288774
# 2024-06-20    0.407197
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    1.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.21
#   RMSE (Root Mean Squared Error): 0.46
#
# --- 메뉴: 'Conference M9' 예측 종료 ---
#
#
# --- 메뉴: 'Convention Hall' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.237765
# 2024-06-17    0.658818
# 2024-06-18    0.698299
# 2024-06-19    0.777241
# 2024-06-20    0.948296
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    1.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.34
#   RMSE (Root Mean Squared Error): 0.58
#
# --- 메뉴: 'Convention Hall' 예측 종료 ---
#
#
# --- 메뉴: 'Cookie Platter' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.524387
# 2024-06-17    1.120251
# 2024-06-18    2.264961
# 2024-06-19    2.567655
# 2024-06-20    4.988894
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    4.0
# 2024-06-19    2.0
# 2024-06-20    4.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 13.73
#   RMSE (Root Mean Squared Error): 3.71
#
# --- 메뉴: 'Cookie Platter' 예측 종료 ---
#
#
# --- 메뉴: 'Grand Ballroom' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.108290
# 2024-06-17    0.259953
# 2024-06-18    0.312741
# 2024-06-19    0.299492
# 2024-06-20    0.523361
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.31
#   RMSE (Root Mean Squared Error): 0.56
#
# --- 메뉴: 'Grand Ballroom' 예측 종료 ---
#
#
# --- 메뉴: 'OPUS 2' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.044807
# 2024-06-17    0.255081
# 2024-06-18    0.413004
# 2024-06-19    0.412911
# 2024-06-20    0.544789
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    1.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 0.19
#   RMSE (Root Mean Squared Error): 0.44
#
# --- 메뉴: 'OPUS 2' 예측 종료 ---
#
#
# --- 메뉴: 'Regular Coffee' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    10.469442
# 2024-06-17    15.324524
# 2024-06-18    33.863970
# 2024-06-19    24.364093
# 2024-06-20    45.798141
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16      0.0
# 2024-06-17      0.0
# 2024-06-18      0.0
# 2024-06-19    255.0
# 2024-06-20     14.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 5289.76
#   RMSE (Root Mean Squared Error): 72.73
#
# --- 메뉴: 'Regular Coffee' 예측 종료 ---
#
#
# --- 메뉴: '골뱅이무침' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.016528
# 2024-06-17   -0.457148
# 2024-06-18   -0.430735
# 2024-06-19   -0.522826
# 2024-06-20   -0.207070
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 16.37
#   RMSE (Root Mean Squared Error): 4.05
#
# --- 메뉴: '골뱅이무침' 예측 종료 ---
#
#
# --- 메뉴: '공깃밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.331816
# 2024-06-17   -0.594094
# 2024-06-18   -0.006775
# 2024-06-19   -0.494516
# 2024-06-20    0.171069
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 8.84
#   RMSE (Root Mean Squared Error): 2.97
#
# --- 메뉴: '공깃밥' 예측 종료 ---
#
#
# --- 메뉴: '돈목살 김치찌개 (밥포함)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.167293
# 2024-06-17    0.325230
# 2024-06-18    0.246303
# 2024-06-19    0.114749
# 2024-06-20    0.127818
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 11.53
#   RMSE (Root Mean Squared Error): 3.40
#
# --- 메뉴: '돈목살 김치찌개 (밥포함)' 예측 종료 ---
#
#
# --- 메뉴: '로제 치즈떡볶이' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.510624
# 2024-06-17   -0.226008
# 2024-06-18   -0.318175
# 2024-06-19   -0.410455
# 2024-06-20   -0.173520
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 6.38
#   RMSE (Root Mean Squared Error): 2.53
#
# --- 메뉴: '로제 치즈떡볶이' 예측 종료 ---
#
#
# --- 메뉴: '마라샹궈' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.144625
# 2024-06-17    0.144992
# 2024-06-18    0.190530
# 2024-06-19    0.515109
# 2024-06-20    0.420699
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.57
#   RMSE (Root Mean Squared Error): 1.25
#
# --- 메뉴: '마라샹궈' 예측 종료 ---
#
#
# --- 메뉴: '매콤 무뼈닭발&계란찜' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.043413
# 2024-06-17   -0.135883
# 2024-06-18   -0.157755
# 2024-06-19   -0.121594
# 2024-06-20    0.115741
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2.64
#   RMSE (Root Mean Squared Error): 1.63
#
# --- 메뉴: '매콤 무뼈닭발&계란찜' 예측 종료 ---
#
#
# --- 메뉴: '모둠 돈육구이(3인)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.065886
# 2024-06-17    0.065834
# 2024-06-18   -0.342902
# 2024-06-19   -0.145853
# 2024-06-20   -0.238254
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 41.57
#   RMSE (Root Mean Squared Error): 6.45
#
# --- 메뉴: '모둠 돈육구이(3인)' 예측 종료 ---
#
#
# --- 메뉴: '삼겹살추가 (200g)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.410399
# 2024-06-17    0.121342
# 2024-06-18    0.028282
# 2024-06-19    0.235583
# 2024-06-20    0.181024
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2.22
#   RMSE (Root Mean Squared Error): 1.49
#
# --- 메뉴: '삼겹살추가 (200g)' 예측 종료 ---
#
#
# --- 메뉴: '야채추가' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.133391
# 2024-06-17    0.028045
# 2024-06-18   -0.037765
# 2024-06-19   -0.011450
# 2024-06-20   -0.050958
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1.35
#   RMSE (Root Mean Squared Error): 1.16
#
# --- 메뉴: '야채추가' 예측 종료 ---
#
#
# --- 메뉴: '왕갈비치킨' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.886763
# 2024-06-17    0.379485
# 2024-06-18    0.621576
# 2024-06-19    0.778445
# 2024-06-20    1.323934
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 4.84
#   RMSE (Root Mean Squared Error): 2.20
#
# --- 메뉴: '왕갈비치킨' 예측 종료 ---
#
#
# --- 메뉴: '주먹밥 (2ea)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.828031
# 2024-06-17    0.420162
# 2024-06-18    0.393863
# 2024-06-19    0.209543
# 2024-06-20    0.275425
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3.49
#   RMSE (Root Mean Squared Error): 1.87
#
# --- 메뉴: '주먹밥 (2ea)' 예측 종료 ---

# %% [markdown]
# 연회장 영업장의 submission 파일 생성

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np
import warnings
from datetime import timedelta

# statsmodels 경고 무시
warnings.filterwarnings("ignore")

# 1. 데이터 불러오기 및 전처리
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/연회장_data.csv')
    test_df_original = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/연회장_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 날짜/시간 인덱스 생성
train_df['date'] = pd.to_datetime(train_df[['year', 'month', 'day']])
test_df_original['date'] = pd.to_datetime(test_df_original[['year', 'month', 'day']])

# 결측값 포함 행 제거
train_df.dropna(subset=['date', 'sum'], inplace=True)
test_df_original.dropna(subset=['date', 'sum'], inplace=True)

# 2. 예측 대상 날짜들 찾기 (모든 메뉴에 대해 공통)
# 테스트 데이터의 전체 날짜 범위
full_test_date_range = pd.date_range(
    start=test_df_original['date'].min(),
    end=test_df_original['date'].max(),
    freq='D'
)

# 테스트 데이터에 실제 값이 존재하는 날짜
dates_with_data = pd.to_datetime(test_df_original['date'].unique())

# 전체 날짜 범위에서 실제 데이터가 있는 날짜를 제외하여 빈 기간 식별
missing_dates = full_test_date_range.difference(dates_with_data)

# 마지막 7일 기간 추가 (테스트 데이터 마지막 날 다음 날부터)
last_test_date = test_df_original['date'].max()
final_week_dates = pd.date_range(
    start=last_test_date + timedelta(days=1),
    periods=7,
    freq='D'
)

# 예측할 날짜 전체 리스트 생성
forecast_dates = missing_dates.append(final_week_dates).sort_values()

# 예측할 날짜 목록 출력
print(f"\n총 {len(forecast_dates)}개의 날짜에 대해 예측을 수행합니다.")
print("예측 날짜 목록:")
print(forecast_dates)

# 3. 고유한 메뉴 목록 추출 및 예측
unique_menus = test_df_original['menu'].unique()
predictions_dict = {}

# 4. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 진행 중... ---")

    # 해당 메뉴에 대한 훈련 데이터 필터링 및 합산
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    train_series = train_menu_df.groupby('date')['sum'].sum().asfreq('D')

    if train_series.empty:
        predictions_dict[menu_item] = np.zeros(len(forecast_dates))
        print(f"  데이터 부족으로 '{menu_item}' 예측값을 0으로 처리합니다.")
        continue

    # Holt-Winters 모델 훈련
    model_hw = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_hw = model_hw.fit()

    # 예측 수행
    menu_predictions_series = fitted_hw.predict(
        start=forecast_dates.min(),
        end=forecast_dates.max()
    )

    # 예측값을 빈 날짜에 맞게 필터링
    final_predictions_for_menu = menu_predictions_series.reindex(forecast_dates)

    # 예측값 저장
    predictions_dict[menu_item] = final_predictions_for_menu.values

# 5. 예측값으로 최종 데이터프레임 생성
final_predictions_df = pd.DataFrame(predictions_dict, index=forecast_dates)

# 열 라벨(column labels) 생성
column_labels = [f"연회장_{menu}" for menu in unique_menus]
final_predictions_df.columns = column_labels

# 6. 예측 파일로 저장
file_name = 'test_predictions_by_date.csv'
final_predictions_df.to_csv(file_name, encoding='utf-8-sig', index=True)

print(f"\n성공적으로 예측이 완료되었습니다. 결과는 '{file_name}' 파일에 저장되었습니다.")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 70개의 날짜에 대해 예측을 수행합니다.
# 예측 날짜 목록:
# DatetimeIndex(['2024-07-14', '2024-07-15', '2024-07-16', '2024-07-17',
#                '2024-07-18', '2024-07-19', '2024-07-20', '2024-08-18',
#                '2024-08-19', '2024-08-20', '2024-08-21', '2024-08-22',
#                '2024-08-23', '2024-08-24', '2024-09-22', '2024-09-23',
#                '2024-09-24', '2024-09-25', '2024-09-26', '2024-09-27',
#                '2024-09-28', '2024-10-27', '2024-10-28', '2024-10-29',
#                '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-02',
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2025-01-05',
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-09',
#                '2025-01-10', '2025-01-11', '2025-02-09', '2025-02-10',
#                '2025-02-11', '2025-02-12', '2025-02-13', '2025-02-14',
#                '2025-02-15', '2025-03-16', '2025-03-17', '2025-03-18',
#                '2025-03-19', '2025-03-20', '2025-03-21', '2025-03-22',
#                '2025-04-20', '2025-04-21', '2025-04-22', '2025-04-23',
#                '2025-04-24', '2025-04-25', '2025-04-26', '2025-05-25',
#                '2025-05-26', '2025-05-27', '2025-05-28', '2025-05-29',
#                '2025-05-30', '2025-05-31'],
#               dtype='datetime64[ns]', freq=None)
#
# --- 메뉴: 'Cass Beer' 예측 진행 중... ---
#
# --- 메뉴: 'Conference L1' 예측 진행 중... ---
#
# --- 메뉴: 'Conference L2' 예측 진행 중... ---
#
# --- 메뉴: 'Conference L3' 예측 진행 중... ---
#
# --- 메뉴: 'Conference M1' 예측 진행 중... ---
#
# --- 메뉴: 'Conference M8' 예측 진행 중... ---
#
# --- 메뉴: 'Conference M9' 예측 진행 중... ---
#
# --- 메뉴: 'Convention Hall' 예측 진행 중... ---
#
# --- 메뉴: 'Cookie Platter' 예측 진행 중... ---
#
# --- 메뉴: 'Grand Ballroom' 예측 진행 중... ---
#
# --- 메뉴: 'OPUS 2' 예측 진행 중... ---
#
# --- 메뉴: 'Regular Coffee' 예측 진행 중... ---
#
# --- 메뉴: '골뱅이무침' 예측 진행 중... ---
#
# --- 메뉴: '공깃밥' 예측 진행 중... ---
#
# --- 메뉴: '돈목살 김치찌개 (밥포함)' 예측 진행 중... ---
#
# --- 메뉴: '로제 치즈떡볶이' 예측 진행 중... ---
#
# --- 메뉴: '마라샹궈' 예측 진행 중... ---
#
# --- 메뉴: '매콤 무뼈닭발&계란찜' 예측 진행 중... ---
#
# --- 메뉴: '모둠 돈육구이(3인)' 예측 진행 중... ---
#
# --- 메뉴: '삼겹살추가 (200g)' 예측 진행 중... ---
#
# --- 메뉴: '야채추가' 예측 진행 중... ---
#
# --- 메뉴: '왕갈비치킨' 예측 진행 중... ---
#
# --- 메뉴: '주먹밥 (2ea)' 예측 진행 중... ---
#
# 성공적으로 예측이 완료되었습니다. 결과는 'test_predictions_by_date.csv' 파일에 저장되었습니다.

# %% [markdown]
# holt-winters 모델 (카페테리아)

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. 데이터 불러오기
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/카페테리아_data.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/카페테리아_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 2. 고유한 메뉴 목록 추출
unique_menus = test_df['menu'].unique()
print(f"\n총 {len(unique_menus)}개의 메뉴에 대해 예측을 시작합니다.")

# 3. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 시작 ---")

    # 해당 메뉴에 대한 훈련/테스트 데이터 필터링
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    test_menu_df = test_df[test_df['menu'] == menu_item].copy()

    # 결측값 포함 행 제거 (날짜 생성 전)
    train_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)
    test_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)

    # 날짜별 'sum' 값 합산 (중복 날짜 제거)
    train_agg = train_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()
    test_agg = test_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()

    if train_agg.empty or test_agg.empty:
        print(f"'{menu_item}' 메뉴의 데이터가 부족하여 예측을 건너뜁니다.")
        continue

    # 날짜 인덱스 생성
    train_agg['date'] = pd.to_datetime(train_agg[['year', 'month', 'day']])
    train_agg.set_index('date', inplace=True)

    test_agg['date'] = pd.to_datetime(test_agg[['year', 'month', 'day']])
    test_agg.set_index('date', inplace=True)

    # 시계열 데이터 선택
    train_series = train_agg['sum']
    test_series = test_agg['sum']

    # 날짜가 비어있는 경우 일별 빈도(D)로 채우기
    train_series = train_series.asfreq('D')
    test_series = test_series.asfreq('D')

    # Holt-Winters 모델 구현 및 훈련
    model = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_model = model.fit()

    # 예측
    forecast_steps = len(test_series)
    predictions = fitted_model.forecast(steps=forecast_steps)

    # 평가
    results_df = pd.DataFrame({
        'actual': test_series,
        'predicted': predictions
    }).dropna()

    if not results_df.empty:
        actual_values = results_df['actual']
        predictions_filtered = results_df['predicted']

        mse = mean_squared_error(actual_values, predictions_filtered)
        rmse = np.sqrt(mse)

        print(f"  예측값 (상위 5개): \n{predictions_filtered.head()}")
        print(f"\n  실제 테스트 데이터 (상위 5개): \n{actual_values.head()}")
        print(f"\n  MSE (Mean Squared Error): {mse:.2f}")
        print(f"  RMSE (Root Mean Squared Error): {rmse:.2f}")
    else:
        print("  예측과 실제값을 비교할 데이터가 부족하여 평가를 건너뜁니다.")

    print(f"\n--- 메뉴: '{menu_item}' 예측 종료 ---\n")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 24개의 메뉴에 대해 예측을 시작합니다.
#
# --- 메뉴: '공깃밥(추가)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    8.559828
# 2024-06-17    1.849007
# 2024-06-18   -2.322145
# 2024-06-19   -3.782312
# 2024-06-20   -2.769287
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16     7.0
# 2024-06-17     0.0
# 2024-06-18     3.0
# 2024-06-19     2.0
# 2024-06-20    17.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2049.58
#   RMSE (Root Mean Squared Error): 45.27
#
# --- 메뉴: '공깃밥(추가)' 예측 종료 ---
#
#
# --- 메뉴: '구슬아이스크림' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.371988
# 2024-06-17   -0.439488
# 2024-06-18   -0.520096
# 2024-06-19   -0.619189
# 2024-06-20   -0.760025
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1812.74
#   RMSE (Root Mean Squared Error): 42.58
#
# --- 메뉴: '구슬아이스크림' 예측 종료 ---
#
#
# --- 메뉴: '단체식 13000(신)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    30.356951
# 2024-06-17    29.313044
# 2024-06-18    63.074911
# 2024-06-19    74.919566
# 2024-06-20    54.564602
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16      0.0
# 2024-06-17      0.0
# 2024-06-18      0.0
# 2024-06-19     85.0
# 2024-06-20    165.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 8170.63
#   RMSE (Root Mean Squared Error): 90.39
#
# --- 메뉴: '단체식 13000(신)' 예측 종료 ---
#
#
# --- 메뉴: '단체식 18000(신)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16     36.718156
# 2024-06-17     73.247017
# 2024-06-18    106.800189
# 2024-06-19     98.707877
# 2024-06-20    114.434509
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16      0.0
# 2024-06-17      0.0
# 2024-06-18     35.0
# 2024-06-19    320.0
# 2024-06-20    426.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 11688.22
#   RMSE (Root Mean Squared Error): 108.11
#
# --- 메뉴: '단체식 18000(신)' 예측 종료 ---
#
#
# --- 메뉴: '돼지고기 김치찌개' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    7.393890
# 2024-06-17    0.547454
# 2024-06-18   -0.387622
# 2024-06-19   -1.030796
# 2024-06-20   -0.290752
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    15.0
# 2024-06-17     0.0
# 2024-06-18     1.0
# 2024-06-19     3.0
# 2024-06-20     2.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2212.53
#   RMSE (Root Mean Squared Error): 47.04
#
# --- 메뉴: '돼지고기 김치찌개' 예측 종료 ---
#
#
# --- 메뉴: '복숭아 아이스티' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.009400
# 2024-06-17    0.007741
# 2024-06-18    0.003229
# 2024-06-19    0.001530
# 2024-06-20   -0.005110
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 578.39
#   RMSE (Root Mean Squared Error): 24.05
#
# --- 메뉴: '복숭아 아이스티' 예측 종료 ---
#
#
# --- 메뉴: '새우 볶음밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    9.331561
# 2024-06-17    2.253352
# 2024-06-18    2.299050
# 2024-06-19    2.747031
# 2024-06-20    3.083549
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    11.0
# 2024-06-17     1.0
# 2024-06-18     0.0
# 2024-06-19     0.0
# 2024-06-20     6.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 836.27
#   RMSE (Root Mean Squared Error): 28.92
#
# --- 메뉴: '새우 볶음밥' 예측 종료 ---
#
#
# --- 메뉴: '새우튀김 우동' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.371313
# 2024-06-17   -0.466292
# 2024-06-18   -0.591358
# 2024-06-19   -0.798985
# 2024-06-20   -1.058484
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1490.48
#   RMSE (Root Mean Squared Error): 38.61
#
# --- 메뉴: '새우튀김 우동' 예측 종료 ---
#
#
# --- 메뉴: '샷 추가' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.168401
# 2024-06-17    0.011715
# 2024-06-18   -0.160680
# 2024-06-19   -0.145252
# 2024-06-20   -0.059844
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 11.98
#   RMSE (Root Mean Squared Error): 3.46
#
# --- 메뉴: '샷 추가' 예측 종료 ---
#
#
# --- 메뉴: '수제 등심 돈까스' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    18.149411
# 2024-06-17     1.816720
# 2024-06-18     3.219284
# 2024-06-19     6.741858
# 2024-06-20    19.794709
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    27.0
# 2024-06-17     0.0
# 2024-06-18     2.0
# 2024-06-19     3.0
# 2024-06-20     7.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 11277.12
#   RMSE (Root Mean Squared Error): 106.19
#
# --- 메뉴: '수제 등심 돈까스' 예측 종료 ---
#
#
# --- 메뉴: '아메리카노(HOT)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.533022
# 2024-06-17   -0.625695
# 2024-06-18   -0.762388
# 2024-06-19   -0.973204
# 2024-06-20   -1.279293
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 6903.99
#   RMSE (Root Mean Squared Error): 83.09
#
# --- 메뉴: '아메리카노(HOT)' 예측 종료 ---
#
#
# --- 메뉴: '아메리카노(ICE)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.000231
# 2024-06-17   -0.000186
# 2024-06-18   -0.000122
# 2024-06-19   -0.000132
# 2024-06-20   -0.000308
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2708.10
#   RMSE (Root Mean Squared Error): 52.04
#
# --- 메뉴: '아메리카노(ICE)' 예측 종료 ---
#
#
# --- 메뉴: '약 고추장 돌솥비빔밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    19.059779
# 2024-06-17     9.057542
# 2024-06-18     4.179266
# 2024-06-19     5.556389
# 2024-06-20     5.414224
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    11.0
# 2024-06-17     1.0
# 2024-06-18     8.0
# 2024-06-19     2.0
# 2024-06-20    10.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1932.02
#   RMSE (Root Mean Squared Error): 43.95
#
# --- 메뉴: '약 고추장 돌솥비빔밥' 예측 종료 ---
#
#
# --- 메뉴: '어린이 돈까스' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    12.122764
# 2024-06-17     4.438359
# 2024-06-18     3.753843
# 2024-06-19     2.925011
# 2024-06-20     3.451247
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    5.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    1.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 236.35
#   RMSE (Root Mean Squared Error): 15.37
#
# --- 메뉴: '어린이 돈까스' 예측 종료 ---
#
#
# --- 메뉴: '오픈푸드' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -3.664731
# 2024-06-17    6.369509
# 2024-06-18    5.038574
# 2024-06-19    8.257549
# 2024-06-20   -2.865705
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1998.76
#   RMSE (Root Mean Squared Error): 44.71
#
# --- 메뉴: '오픈푸드' 예측 종료 ---
#
#
# --- 메뉴: '진사골 설렁탕' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.005069
# 2024-06-17    0.215395
# 2024-06-18    0.413966
# 2024-06-19    0.439184
# 2024-06-20    0.278712
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 623.42
#   RMSE (Root Mean Squared Error): 24.97
#
# --- 메뉴: '진사골 설렁탕' 예측 종료 ---
#
#
# --- 메뉴: '짜장면' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    13.194749
# 2024-06-17    -0.192162
# 2024-06-18    -0.769066
# 2024-06-19     1.328549
# 2024-06-20     3.844088
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    17.0
# 2024-06-17     0.0
# 2024-06-18     0.0
# 2024-06-19     2.0
# 2024-06-20     1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1690.00
#   RMSE (Root Mean Squared Error): 41.11
#
# --- 메뉴: '짜장면' 예측 종료 ---
#
#
# --- 메뉴: '짜장밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    1.510591
# 2024-06-17    0.485093
# 2024-06-18    0.164863
# 2024-06-19    0.578637
# 2024-06-20    0.820040
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    3.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 35.38
#   RMSE (Root Mean Squared Error): 5.95
#
# --- 메뉴: '짜장밥' 예측 종료 ---
#
#
# --- 메뉴: '짬뽕' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    4.438851
# 2024-06-17   -0.177424
# 2024-06-18   -0.579993
# 2024-06-19    1.153531
# 2024-06-20    1.617602
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    4.0
# 2024-06-17    1.0
# 2024-06-18    1.0
# 2024-06-19    2.0
# 2024-06-20    1.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 827.82
#   RMSE (Root Mean Squared Error): 28.77
#
# --- 메뉴: '짬뽕' 예측 종료 ---
#
#
# --- 메뉴: '짬뽕밥' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.141459
# 2024-06-17    0.007262
# 2024-06-18    0.099235
# 2024-06-19    0.291875
# 2024-06-20    1.588928
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    4.0
# 2024-06-17    1.0
# 2024-06-18    0.0
# 2024-06-19    4.0
# 2024-06-20    3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 213.13
#   RMSE (Root Mean Squared Error): 14.60
#
# --- 메뉴: '짬뽕밥' 예측 종료 ---
#
#
# --- 메뉴: '치즈돈까스' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -1.770204
# 2024-06-17   -3.316764
# 2024-06-18   -3.676681
# 2024-06-19   -1.943193
# 2024-06-20    2.154136
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    11.0
# 2024-06-17     1.0
# 2024-06-18     0.0
# 2024-06-19     1.0
# 2024-06-20     3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3714.02
#   RMSE (Root Mean Squared Error): 60.94
#
# --- 메뉴: '치즈돈까스' 예측 종료 ---
#
#
# --- 메뉴: '카페라떼(HOT)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16   -0.104270
# 2024-06-17   -0.143490
# 2024-06-18   -0.254639
# 2024-06-19   -0.494042
# 2024-06-20   -0.834192
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2818.44
#   RMSE (Root Mean Squared Error): 53.09
#
# --- 메뉴: '카페라떼(HOT)' 예측 종료 ---
#
#
# --- 메뉴: '카페라떼(ICE)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    0.017674
# 2024-06-17    0.006390
# 2024-06-18    0.004179
# 2024-06-19   -0.000903
# 2024-06-20   -0.006714
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 135.35
#   RMSE (Root Mean Squared Error): 11.63
#
# --- 메뉴: '카페라떼(ICE)' 예측 종료 ---
#
#
# --- 메뉴: '한상 삼겹구이 정식(2인) 소요시간 약 15~20분' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.764299
# 2024-06-17   -0.740337
# 2024-06-18   -1.266101
# 2024-06-19    1.275725
# 2024-06-20    5.071927
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    7.0
# 2024-06-17    0.0
# 2024-06-18    1.0
# 2024-06-19    2.0
# 2024-06-20    6.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 57.40
#   RMSE (Root Mean Squared Error): 7.58
#
# --- 메뉴: '한상 삼겹구이 정식(2인) 소요시간 약 15~20분' 예측 종료 ---

# %% [markdown]
# 카페테리아 영업장의 submission 파일 생성

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np
import warnings
from datetime import timedelta

# statsmodels 경고 무시
warnings.filterwarnings("ignore")

# 1. 데이터 불러오기 및 전처리
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/카페테리아_data.csv')
    test_df_original = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/카페테리아_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 날짜/시간 인덱스 생성
train_df['date'] = pd.to_datetime(train_df[['year', 'month', 'day']])
test_df_original['date'] = pd.to_datetime(test_df_original[['year', 'month', 'day']])

# 결측값 포함 행 제거
train_df.dropna(subset=['date', 'sum'], inplace=True)
test_df_original.dropna(subset=['date', 'sum'], inplace=True)

# 2. 예측 대상 날짜들 찾기 (모든 메뉴에 대해 공통)
# 테스트 데이터의 전체 날짜 범위
full_test_date_range = pd.date_range(
    start=test_df_original['date'].min(),
    end=test_df_original['date'].max(),
    freq='D'
)

# 테스트 데이터에 실제 값이 존재하는 날짜
dates_with_data = pd.to_datetime(test_df_original['date'].unique())

# 전체 날짜 범위에서 실제 데이터가 있는 날짜를 제외하여 빈 기간 식별
missing_dates = full_test_date_range.difference(dates_with_data)

# 마지막 7일 기간 추가 (테스트 데이터 마지막 날 다음 날부터)
last_test_date = test_df_original['date'].max()
final_week_dates = pd.date_range(
    start=last_test_date + timedelta(days=1),
    periods=7,
    freq='D'
)

# 예측할 날짜 전체 리스트 생성
forecast_dates = missing_dates.append(final_week_dates).sort_values()

# 예측할 날짜 목록 출력
print(f"\n총 {len(forecast_dates)}개의 날짜에 대해 예측을 수행합니다.")
print("예측 날짜 목록:")
print(forecast_dates)

# 3. 고유한 메뉴 목록 추출 및 예측
unique_menus = test_df_original['menu'].unique()
predictions_dict = {}

# 4. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 진행 중... ---")

    # 해당 메뉴에 대한 훈련 데이터 필터링 및 합산
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    train_series = train_menu_df.groupby('date')['sum'].sum().asfreq('D')

    if train_series.empty:
        predictions_dict[menu_item] = np.zeros(len(forecast_dates))
        print(f"  데이터 부족으로 '{menu_item}' 예측값을 0으로 처리합니다.")
        continue

    # Holt-Winters 모델 훈련
    model_hw = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_hw = model_hw.fit()

    # 예측 수행
    menu_predictions_series = fitted_hw.predict(
        start=forecast_dates.min(),
        end=forecast_dates.max()
    )

    # 예측값을 빈 날짜에 맞게 필터링
    final_predictions_for_menu = menu_predictions_series.reindex(forecast_dates)

    # 예측값 저장
    predictions_dict[menu_item] = final_predictions_for_menu.values

# 5. 예측값으로 최종 데이터프레임 생성
final_predictions_df = pd.DataFrame(predictions_dict, index=forecast_dates)

# 열 라벨(column labels) 생성
column_labels = [f"카페테리아_{menu}" for menu in unique_menus]
final_predictions_df.columns = column_labels

# 6. 예측 파일로 저장
file_name = 'test_predictions_by_date.csv'
final_predictions_df.to_csv(file_name, encoding='utf-8-sig', index=True)

print(f"\n성공적으로 예측이 완료되었습니다. 결과는 '{file_name}' 파일에 저장되었습니다.")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 70개의 날짜에 대해 예측을 수행합니다.
# 예측 날짜 목록:
# DatetimeIndex(['2024-07-14', '2024-07-15', '2024-07-16', '2024-07-17',
#                '2024-07-18', '2024-07-19', '2024-07-20', '2024-08-18',
#                '2024-08-19', '2024-08-20', '2024-08-21', '2024-08-22',
#                '2024-08-23', '2024-08-24', '2024-09-22', '2024-09-23',
#                '2024-09-24', '2024-09-25', '2024-09-26', '2024-09-27',
#                '2024-09-28', '2024-10-27', '2024-10-28', '2024-10-29',
#                '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-02',
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2025-01-05',
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-09',
#                '2025-01-10', '2025-01-11', '2025-02-09', '2025-02-10',
#                '2025-02-11', '2025-02-12', '2025-02-13', '2025-02-14',
#                '2025-02-15', '2025-03-16', '2025-03-17', '2025-03-18',
#                '2025-03-19', '2025-03-20', '2025-03-21', '2025-03-22',
#                '2025-04-20', '2025-04-21', '2025-04-22', '2025-04-23',
#                '2025-04-24', '2025-04-25', '2025-04-26', '2025-05-25',
#                '2025-05-26', '2025-05-27', '2025-05-28', '2025-05-29',
#                '2025-05-30', '2025-05-31'],
#               dtype='datetime64[ns]', freq=None)
#
# --- 메뉴: '공깃밥(추가)' 예측 진행 중... ---
#
# --- 메뉴: '구슬아이스크림' 예측 진행 중... ---
#
# --- 메뉴: '단체식 13000(신)' 예측 진행 중... ---
#
# --- 메뉴: '단체식 18000(신)' 예측 진행 중... ---
#
# --- 메뉴: '돼지고기 김치찌개' 예측 진행 중... ---
#
# --- 메뉴: '복숭아 아이스티' 예측 진행 중... ---
#
# --- 메뉴: '새우 볶음밥' 예측 진행 중... ---
#
# --- 메뉴: '새우튀김 우동' 예측 진행 중... ---
#
# --- 메뉴: '샷 추가' 예측 진행 중... ---
#
# --- 메뉴: '수제 등심 돈까스' 예측 진행 중... ---
#
# --- 메뉴: '아메리카노(HOT)' 예측 진행 중... ---
#
# --- 메뉴: '아메리카노(ICE)' 예측 진행 중... ---
#
# --- 메뉴: '약 고추장 돌솥비빔밥' 예측 진행 중... ---
#
# --- 메뉴: '어린이 돈까스' 예측 진행 중... ---
#
# --- 메뉴: '오픈푸드' 예측 진행 중... ---
#
# --- 메뉴: '진사골 설렁탕' 예측 진행 중... ---
#
# --- 메뉴: '짜장면' 예측 진행 중... ---
#
# --- 메뉴: '짜장밥' 예측 진행 중... ---
#
# --- 메뉴: '짬뽕' 예측 진행 중... ---
#
# --- 메뉴: '짬뽕밥' 예측 진행 중... ---
#
# --- 메뉴: '치즈돈까스' 예측 진행 중... ---
#
# --- 메뉴: '카페라떼(HOT)' 예측 진행 중... ---
#
# --- 메뉴: '카페라떼(ICE)' 예측 진행 중... ---
#
# --- 메뉴: '한상 삼겹구이 정식(2인) 소요시간 약 15~20분' 예측 진행 중... ---
#
# 성공적으로 예측이 완료되었습니다. 결과는 'test_predictions_by_date.csv' 파일에 저장되었습니다.

# %% [markdown]
# holt-winters 모델 (포레스트릿)

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. 데이터 불러오기
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/포레스트릿_data.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/포레스트릿_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 2. 고유한 메뉴 목록 추출
unique_menus = test_df['menu'].unique()
print(f"\n총 {len(unique_menus)}개의 메뉴에 대해 예측을 시작합니다.")

# 3. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 시작 ---")

    # 해당 메뉴에 대한 훈련/테스트 데이터 필터링
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    test_menu_df = test_df[test_df['menu'] == menu_item].copy()

    # 결측값 포함 행 제거 (날짜 생성 전)
    train_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)
    test_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)

    # 날짜별 'sum' 값 합산 (중복 날짜 제거)
    train_agg = train_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()
    test_agg = test_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()

    if train_agg.empty or test_agg.empty:
        print(f"'{menu_item}' 메뉴의 데이터가 부족하여 예측을 건너뜁니다.")
        continue

    # 날짜 인덱스 생성
    train_agg['date'] = pd.to_datetime(train_agg[['year', 'month', 'day']])
    train_agg.set_index('date', inplace=True)

    test_agg['date'] = pd.to_datetime(test_agg[['year', 'month', 'day']])
    test_agg.set_index('date', inplace=True)

    # 시계열 데이터 선택
    train_series = train_agg['sum']
    test_series = test_agg['sum']

    # 날짜가 비어있는 경우 일별 빈도(D)로 채우기
    train_series = train_series.asfreq('D')
    test_series = test_series.asfreq('D')

    # Holt-Winters 모델 구현 및 훈련
    model = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_model = model.fit()

    # 예측
    forecast_steps = len(test_series)
    predictions = fitted_model.forecast(steps=forecast_steps)

    # 평가
    results_df = pd.DataFrame({
        'actual': test_series,
        'predicted': predictions
    }).dropna()

    if not results_df.empty:
        actual_values = results_df['actual']
        predictions_filtered = results_df['predicted']

        mse = mean_squared_error(actual_values, predictions_filtered)
        rmse = np.sqrt(mse)

        print(f"  예측값 (상위 5개): \n{predictions_filtered.head()}")
        print(f"\n  실제 테스트 데이터 (상위 5개): \n{actual_values.head()}")
        print(f"\n  MSE (Mean Squared Error): {mse:.2f}")
        print(f"  RMSE (Root Mean Squared Error): {rmse:.2f}")
    else:
        print("  예측과 실제값을 비교할 데이터가 부족하여 평가를 건너뜁니다.")

    print(f"\n--- 메뉴: '{menu_item}' 예측 종료 ---\n")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 12개의 메뉴에 대해 예측을 시작합니다.
#
# --- 메뉴: '꼬치어묵' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    4.561410
# 2024-06-17   -5.589221
# 2024-06-18   -6.357947
# 2024-06-19   -6.530669
# 2024-06-20   -5.491939
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 99471.18
#   RMSE (Root Mean Squared Error): 315.39
#
# --- 메뉴: '꼬치어묵' 예측 종료 ---
#
#
# --- 메뉴: '떡볶이' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    8.853808
# 2024-06-17   -3.576116
# 2024-06-18   -3.857501
# 2024-06-19   -3.750216
# 2024-06-20    0.926445
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    5.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 32069.50
#   RMSE (Root Mean Squared Error): 179.08
#
# --- 메뉴: '떡볶이' 예측 종료 ---
#
#
# --- 메뉴: '복숭아 아이스티' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16     3.135355
# 2024-06-17    -9.407486
# 2024-06-18   -13.231674
# 2024-06-19   -13.085299
# 2024-06-20   -10.390963
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    0.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 4201.35
#   RMSE (Root Mean Squared Error): 64.82
#
# --- 메뉴: '복숭아 아이스티' 예측 종료 ---
#
#
# --- 메뉴: '생수' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    18.015730
# 2024-06-17    -2.974045
# 2024-06-18    -2.988789
# 2024-06-19    -3.453385
# 2024-06-20     6.997532
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    10.0
# 2024-06-17     0.0
# 2024-06-18     0.0
# 2024-06-19     0.0
# 2024-06-20     0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 27519.97
#   RMSE (Root Mean Squared Error): 165.89
#
# --- 메뉴: '생수' 예측 종료 ---
#
#
# --- 메뉴: '스프라이트' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.742229
# 2024-06-17   -1.189063
# 2024-06-18   -1.319254
# 2024-06-19   -1.550370
# 2024-06-20   -0.214559
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1507.65
#   RMSE (Root Mean Squared Error): 38.83
#
# --- 메뉴: '스프라이트' 예측 종료 ---
#
#
# --- 메뉴: '아메리카노(HOT)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.785908
# 2024-06-17   -1.677431
# 2024-06-18   -1.925086
# 2024-06-19   -0.933202
# 2024-06-20   -1.854253
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    1.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 4571.26
#   RMSE (Root Mean Squared Error): 67.61
#
# --- 메뉴: '아메리카노(HOT)' 예측 종료 ---
#
#
# --- 메뉴: '아메리카노(ICE)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    31.253513
# 2024-06-17    -9.051060
# 2024-06-18    -8.972619
# 2024-06-19   -10.081933
# 2024-06-20    -1.057270
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    36.0
# 2024-06-17     0.0
# 2024-06-18     0.0
# 2024-06-19     0.0
# 2024-06-20     0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3861.02
#   RMSE (Root Mean Squared Error): 62.14
#
# --- 메뉴: '아메리카노(ICE)' 예측 종료 ---
#
#
# --- 메뉴: '치즈 핫도그' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    10.719227
# 2024-06-17    -2.253614
# 2024-06-18    -2.443244
# 2024-06-19    -2.279638
# 2024-06-20     2.868306
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    8.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 15801.38
#   RMSE (Root Mean Squared Error): 125.70
#
# --- 메뉴: '치즈 핫도그' 예측 종료 ---
#
#
# --- 메뉴: '카페라떼(HOT)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    2.767239
# 2024-06-17   -0.790351
# 2024-06-18   -0.757118
# 2024-06-19   -0.540764
# 2024-06-20   -0.607732
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1673.73
#   RMSE (Root Mean Squared Error): 40.91
#
# --- 메뉴: '카페라떼(HOT)' 예측 종료 ---
#
#
# --- 메뉴: '카페라떼(ICE)' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    5.768750
# 2024-06-17    0.610529
# 2024-06-18   -0.230744
# 2024-06-19   -0.520818
# 2024-06-20   -0.087629
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    12.0
# 2024-06-17     0.0
# 2024-06-18     0.0
# 2024-06-19     0.0
# 2024-06-20     0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 62.48
#   RMSE (Root Mean Squared Error): 7.90
#
# --- 메뉴: '카페라떼(ICE)' 예측 종료 ---
#
#
# --- 메뉴: '코카콜라' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    3.308295
# 2024-06-17   -2.526010
# 2024-06-18   -2.627251
# 2024-06-19   -2.872921
# 2024-06-20    0.063397
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    4.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 7842.44
#   RMSE (Root Mean Squared Error): 88.56
#
# --- 메뉴: '코카콜라' 예측 종료 ---
#
#
# --- 메뉴: '페스츄리 소시지' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    4.630330
# 2024-06-17   -0.728252
# 2024-06-18   -0.942241
# 2024-06-19   -0.835531
# 2024-06-20   -1.140094
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    2.0
# 2024-06-17    0.0
# 2024-06-18    0.0
# 2024-06-19    0.0
# 2024-06-20    0.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3848.16
#   RMSE (Root Mean Squared Error): 62.03
#
# --- 메뉴: '페스츄리 소시지' 예측 종료 ---

# %% [markdown]
# 포레스트릿 영업장의 submission 파일 생성

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np
import warnings
from datetime import timedelta

# statsmodels 경고 무시
warnings.filterwarnings("ignore")

# 1. 데이터 불러오기 및 전처리
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/포레스트릿_data.csv')
    test_df_original = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/포레스트릿_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 날짜/시간 인덱스 생성
train_df['date'] = pd.to_datetime(train_df[['year', 'month', 'day']])
test_df_original['date'] = pd.to_datetime(test_df_original[['year', 'month', 'day']])

# 결측값 포함 행 제거
train_df.dropna(subset=['date', 'sum'], inplace=True)
test_df_original.dropna(subset=['date', 'sum'], inplace=True)

# 2. 예측 대상 날짜들 찾기 (모든 메뉴에 대해 공통)
# 테스트 데이터의 전체 날짜 범위
full_test_date_range = pd.date_range(
    start=test_df_original['date'].min(),
    end=test_df_original['date'].max(),
    freq='D'
)

# 테스트 데이터에 실제 값이 존재하는 날짜
dates_with_data = pd.to_datetime(test_df_original['date'].unique())

# 전체 날짜 범위에서 실제 데이터가 있는 날짜를 제외하여 빈 기간 식별
missing_dates = full_test_date_range.difference(dates_with_data)

# 마지막 7일 기간 추가 (테스트 데이터 마지막 날 다음 날부터)
last_test_date = test_df_original['date'].max()
final_week_dates = pd.date_range(
    start=last_test_date + timedelta(days=1),
    periods=7,
    freq='D'
)

# 예측할 날짜 전체 리스트 생성
forecast_dates = missing_dates.append(final_week_dates).sort_values()

# 예측할 날짜 목록 출력
print(f"\n총 {len(forecast_dates)}개의 날짜에 대해 예측을 수행합니다.")
print("예측 날짜 목록:")
print(forecast_dates)

# 3. 고유한 메뉴 목록 추출 및 예측
unique_menus = test_df_original['menu'].unique()
predictions_dict = {}

# 4. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 진행 중... ---")

    # 해당 메뉴에 대한 훈련 데이터 필터링 및 합산
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    train_series = train_menu_df.groupby('date')['sum'].sum().asfreq('D')

    if train_series.empty:
        predictions_dict[menu_item] = np.zeros(len(forecast_dates))
        print(f"  데이터 부족으로 '{menu_item}' 예측값을 0으로 처리합니다.")
        continue

    # Holt-Winters 모델 훈련
    model_hw = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_hw = model_hw.fit()

    # 예측 수행
    menu_predictions_series = fitted_hw.predict(
        start=forecast_dates.min(),
        end=forecast_dates.max()
    )

    # 예측값을 빈 날짜에 맞게 필터링
    final_predictions_for_menu = menu_predictions_series.reindex(forecast_dates)

    # 예측값 저장
    predictions_dict[menu_item] = final_predictions_for_menu.values

# 5. 예측값으로 최종 데이터프레임 생성
final_predictions_df = pd.DataFrame(predictions_dict, index=forecast_dates)

# 열 라벨(column labels) 생성
column_labels = [f"포레스트릿_{menu}" for menu in unique_menus]
final_predictions_df.columns = column_labels

# 6. 예측 파일로 저장
file_name = 'test_predictions_by_date.csv'
final_predictions_df.to_csv(file_name, encoding='utf-8-sig', index=True)

print(f"\n성공적으로 예측이 완료되었습니다. 결과는 '{file_name}' 파일에 저장되었습니다.")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 70개의 날짜에 대해 예측을 수행합니다.
# 예측 날짜 목록:
# DatetimeIndex(['2024-07-14', '2024-07-15', '2024-07-16', '2024-07-17',
#                '2024-07-18', '2024-07-19', '2024-07-20', '2024-08-18',
#                '2024-08-19', '2024-08-20', '2024-08-21', '2024-08-22',
#                '2024-08-23', '2024-08-24', '2024-09-22', '2024-09-23',
#                '2024-09-24', '2024-09-25', '2024-09-26', '2024-09-27',
#                '2024-09-28', '2024-10-27', '2024-10-28', '2024-10-29',
#                '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-02',
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2025-01-05',
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-09',
#                '2025-01-10', '2025-01-11', '2025-02-09', '2025-02-10',
#                '2025-02-11', '2025-02-12', '2025-02-13', '2025-02-14',
#                '2025-02-15', '2025-03-16', '2025-03-17', '2025-03-18',
#                '2025-03-19', '2025-03-20', '2025-03-21', '2025-03-22',
#                '2025-04-20', '2025-04-21', '2025-04-22', '2025-04-23',
#                '2025-04-24', '2025-04-25', '2025-04-26', '2025-05-25',
#                '2025-05-26', '2025-05-27', '2025-05-28', '2025-05-29',
#                '2025-05-30', '2025-05-31'],
#               dtype='datetime64[ns]', freq=None)
#
# --- 메뉴: '꼬치어묵' 예측 진행 중... ---
#
# --- 메뉴: '떡볶이' 예측 진행 중... ---
#
# --- 메뉴: '복숭아 아이스티' 예측 진행 중... ---
#
# --- 메뉴: '생수' 예측 진행 중... ---
#
# --- 메뉴: '스프라이트' 예측 진행 중... ---
#
# --- 메뉴: '아메리카노(HOT)' 예측 진행 중... ---
#
# --- 메뉴: '아메리카노(ICE)' 예측 진행 중... ---
#
# --- 메뉴: '치즈 핫도그' 예측 진행 중... ---
#
# --- 메뉴: '카페라떼(HOT)' 예측 진행 중... ---
#
# --- 메뉴: '카페라떼(ICE)' 예측 진행 중... ---
#
# --- 메뉴: '코카콜라' 예측 진행 중... ---
#
# --- 메뉴: '페스츄리 소시지' 예측 진행 중... ---
#
# 성공적으로 예측이 완료되었습니다. 결과는 'test_predictions_by_date.csv' 파일에 저장되었습니다.

# %% [markdown]
# holt-winters 모델 (화담숲주막)

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. 데이터 불러오기
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/화담숲주막_data.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/화담숲주막_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 2. 고유한 메뉴 목록 추출
unique_menus = test_df['menu'].unique()
print(f"\n총 {len(unique_menus)}개의 메뉴에 대해 예측을 시작합니다.")

# 3. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 시작 ---")

    # 해당 메뉴에 대한 훈련/테스트 데이터 필터링
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    test_menu_df = test_df[test_df['menu'] == menu_item].copy()

    # 결측값 포함 행 제거 (날짜 생성 전)
    train_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)
    test_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)

    # 날짜별 'sum' 값 합산 (중복 날짜 제거)
    train_agg = train_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()
    test_agg = test_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()

    if train_agg.empty or test_agg.empty:
        print(f"'{menu_item}' 메뉴의 데이터가 부족하여 예측을 건너뜁니다.")
        continue

    # 날짜 인덱스 생성
    train_agg['date'] = pd.to_datetime(train_agg[['year', 'month', 'day']])
    train_agg.set_index('date', inplace=True)

    test_agg['date'] = pd.to_datetime(test_agg[['year', 'month', 'day']])
    test_agg.set_index('date', inplace=True)

    # 시계열 데이터 선택
    train_series = train_agg['sum']
    test_series = test_agg['sum']

    # 날짜가 비어있는 경우 일별 빈도(D)로 채우기
    train_series = train_series.asfreq('D')
    test_series = test_series.asfreq('D')

    # Holt-Winters 모델 구현 및 훈련
    model = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_model = model.fit()

    # 예측
    forecast_steps = len(test_series)
    predictions = fitted_model.forecast(steps=forecast_steps)

    # 평가
    results_df = pd.DataFrame({
        'actual': test_series,
        'predicted': predictions
    }).dropna()

    if not results_df.empty:
        actual_values = results_df['actual']
        predictions_filtered = results_df['predicted']

        mse = mean_squared_error(actual_values, predictions_filtered)
        rmse = np.sqrt(mse)

        print(f"  예측값 (상위 5개): \n{predictions_filtered.head()}")
        print(f"\n  실제 테스트 데이터 (상위 5개): \n{actual_values.head()}")
        print(f"\n  MSE (Mean Squared Error): {mse:.2f}")
        print(f"  RMSE (Root Mean Squared Error): {rmse:.2f}")
    else:
        print("  예측과 실제값을 비교할 데이터가 부족하여 평가를 건너뜁니다.")

    print(f"\n--- 메뉴: '{menu_item}' 예측 종료 ---\n")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 8개의 메뉴에 대해 예측을 시작합니다.
#
# --- 메뉴: '느린마을 막걸리' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    46.438598
# 2024-06-17   -16.178481
# 2024-06-18     7.850430
# 2024-06-19    11.373002
# 2024-06-20    21.768943
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    33.0
# 2024-06-17     0.0
# 2024-06-18     9.0
# 2024-06-19    10.0
# 2024-06-20    19.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2441.34
#   RMSE (Root Mean Squared Error): 49.41
#
# --- 메뉴: '느린마을 막걸리' 예측 종료 ---
#
#
# --- 메뉴: '단호박 식혜 ' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    25.887446
# 2024-06-17     5.398490
# 2024-06-18    14.082782
# 2024-06-19    10.920963
# 2024-06-20    12.957177
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    33.0
# 2024-06-17     0.0
# 2024-06-18     8.0
# 2024-06-19     9.0
# 2024-06-20     5.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 739.03
#   RMSE (Root Mean Squared Error): 27.19
#
# --- 메뉴: '단호박 식혜 ' 예측 종료 ---
#
#
# --- 메뉴: '병천순대' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    43.787953
# 2024-06-17   -19.232049
# 2024-06-18     6.788314
# 2024-06-19    11.132557
# 2024-06-20    27.651234
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    48.0
# 2024-06-17     0.0
# 2024-06-18    17.0
# 2024-06-19     8.0
# 2024-06-20    17.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1617.41
#   RMSE (Root Mean Squared Error): 40.22
#
# --- 메뉴: '병천순대' 예측 종료 ---
#
#
# --- 메뉴: '스프라이트' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    23.774993
# 2024-06-17     7.772948
# 2024-06-18    12.670228
# 2024-06-19    11.526968
# 2024-06-20    11.974344
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    18.0
# 2024-06-17     0.0
# 2024-06-18     2.0
# 2024-06-19     2.0
# 2024-06-20     3.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 406.29
#   RMSE (Root Mean Squared Error): 20.16
#
# --- 메뉴: '스프라이트' 예측 종료 ---
#
#
# --- 메뉴: '참살이 막걸리' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    46.442478
# 2024-06-17   -10.282168
# 2024-06-18    17.305822
# 2024-06-19    22.342543
# 2024-06-20    34.761816
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    51.0
# 2024-06-17     0.0
# 2024-06-18    14.0
# 2024-06-19     3.0
# 2024-06-20     6.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1420.05
#   RMSE (Root Mean Squared Error): 37.68
#
# --- 메뉴: '참살이 막걸리' 예측 종료 ---
#
#
# --- 메뉴: '찹쌀식혜' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    45.536265
# 2024-06-17   -14.643366
# 2024-06-18     6.818797
# 2024-06-19    12.889861
# 2024-06-20    22.027106
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    47.0
# 2024-06-17     0.0
# 2024-06-18    11.0
# 2024-06-19    13.0
# 2024-06-20    11.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 1810.92
#   RMSE (Root Mean Squared Error): 42.55
#
# --- 메뉴: '찹쌀식혜' 예측 종료 ---
#
#
# --- 메뉴: '콜라' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    20.919304
# 2024-06-17    -2.851412
# 2024-06-18     5.229311
# 2024-06-19     1.694571
# 2024-06-20     4.196712
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    25.0
# 2024-06-17     0.0
# 2024-06-18     2.0
# 2024-06-19     5.0
# 2024-06-20     8.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 644.66
#   RMSE (Root Mean Squared Error): 25.39
#
# --- 메뉴: '콜라' 예측 종료 ---
#
#
# --- 메뉴: '해물파전' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    142.333921
# 2024-06-17    -45.410993
# 2024-06-18     26.424239
# 2024-06-19     45.230510
# 2024-06-20     88.716940
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    165.0
# 2024-06-17      0.0
# 2024-06-18     47.0
# 2024-06-19     30.0
# 2024-06-20     37.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 42427.40
#   RMSE (Root Mean Squared Error): 205.98
#
# --- 메뉴: '해물파전' 예측 종료 ---

# %% [markdown]
# 화담숲주막 영업장의 submission 파일 생성

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np
import warnings
from datetime import timedelta

# statsmodels 경고 무시
warnings.filterwarnings("ignore")

# 1. 데이터 불러오기 및 전처리
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/화담숲주막_data.csv')
    test_df_original = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/화담숲주막_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 날짜/시간 인덱스 생성
train_df['date'] = pd.to_datetime(train_df[['year', 'month', 'day']])
test_df_original['date'] = pd.to_datetime(test_df_original[['year', 'month', 'day']])

# 결측값 포함 행 제거
train_df.dropna(subset=['date', 'sum'], inplace=True)
test_df_original.dropna(subset=['date', 'sum'], inplace=True)

# 2. 예측 대상 날짜들 찾기 (모든 메뉴에 대해 공통)
# 테스트 데이터의 전체 날짜 범위
full_test_date_range = pd.date_range(
    start=test_df_original['date'].min(),
    end=test_df_original['date'].max(),
    freq='D'
)

# 테스트 데이터에 실제 값이 존재하는 날짜
dates_with_data = pd.to_datetime(test_df_original['date'].unique())

# 전체 날짜 범위에서 실제 데이터가 있는 날짜를 제외하여 빈 기간 식별
missing_dates = full_test_date_range.difference(dates_with_data)

# 마지막 7일 기간 추가 (테스트 데이터 마지막 날 다음 날부터)
last_test_date = test_df_original['date'].max()
final_week_dates = pd.date_range(
    start=last_test_date + timedelta(days=1),
    periods=7,
    freq='D'
)

# 예측할 날짜 전체 리스트 생성
forecast_dates = missing_dates.append(final_week_dates).sort_values()

# 예측할 날짜 목록 출력
print(f"\n총 {len(forecast_dates)}개의 날짜에 대해 예측을 수행합니다.")
print("예측 날짜 목록:")
print(forecast_dates)

# 3. 고유한 메뉴 목록 추출 및 예측
unique_menus = test_df_original['menu'].unique()
predictions_dict = {}

# 4. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 진행 중... ---")

    # 해당 메뉴에 대한 훈련 데이터 필터링 및 합산
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    train_series = train_menu_df.groupby('date')['sum'].sum().asfreq('D')

    if train_series.empty:
        predictions_dict[menu_item] = np.zeros(len(forecast_dates))
        print(f"  데이터 부족으로 '{menu_item}' 예측값을 0으로 처리합니다.")
        continue

    # Holt-Winters 모델 훈련
    model_hw = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_hw = model_hw.fit()

    # 예측 수행
    menu_predictions_series = fitted_hw.predict(
        start=forecast_dates.min(),
        end=forecast_dates.max()
    )

    # 예측값을 빈 날짜에 맞게 필터링
    final_predictions_for_menu = menu_predictions_series.reindex(forecast_dates)

    # 예측값 저장
    predictions_dict[menu_item] = final_predictions_for_menu.values

# 5. 예측값으로 최종 데이터프레임 생성
final_predictions_df = pd.DataFrame(predictions_dict, index=forecast_dates)

# 열 라벨(column labels) 생성
column_labels = [f"화담숲주막_{menu}" for menu in unique_menus]
final_predictions_df.columns = column_labels

# 6. 예측 파일로 저장
file_name = 'test_predictions_by_date.csv'
final_predictions_df.to_csv(file_name, encoding='utf-8-sig', index=True)

print(f"\n성공적으로 예측이 완료되었습니다. 결과는 '{file_name}' 파일에 저장되었습니다.")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 70개의 날짜에 대해 예측을 수행합니다.
# 예측 날짜 목록:
# DatetimeIndex(['2024-07-14', '2024-07-15', '2024-07-16', '2024-07-17',
#                '2024-07-18', '2024-07-19', '2024-07-20', '2024-08-18',
#                '2024-08-19', '2024-08-20', '2024-08-21', '2024-08-22',
#                '2024-08-23', '2024-08-24', '2024-09-22', '2024-09-23',
#                '2024-09-24', '2024-09-25', '2024-09-26', '2024-09-27',
#                '2024-09-28', '2024-10-27', '2024-10-28', '2024-10-29',
#                '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-02',
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2025-01-05',
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-09',
#                '2025-01-10', '2025-01-11', '2025-02-09', '2025-02-10',
#                '2025-02-11', '2025-02-12', '2025-02-13', '2025-02-14',
#                '2025-02-15', '2025-03-16', '2025-03-17', '2025-03-18',
#                '2025-03-19', '2025-03-20', '2025-03-21', '2025-03-22',
#                '2025-04-20', '2025-04-21', '2025-04-22', '2025-04-23',
#                '2025-04-24', '2025-04-25', '2025-04-26', '2025-05-25',
#                '2025-05-26', '2025-05-27', '2025-05-28', '2025-05-29',
#                '2025-05-30', '2025-05-31'],
#               dtype='datetime64[ns]', freq=None)
#
# --- 메뉴: '느린마을 막걸리' 예측 진행 중... ---
#
# --- 메뉴: '단호박 식혜 ' 예측 진행 중... ---
#
# --- 메뉴: '병천순대' 예측 진행 중... ---
#
# --- 메뉴: '스프라이트' 예측 진행 중... ---
#
# --- 메뉴: '참살이 막걸리' 예측 진행 중... ---
#
# --- 메뉴: '찹쌀식혜' 예측 진행 중... ---
#
# --- 메뉴: '콜라' 예측 진행 중... ---
#
# --- 메뉴: '해물파전' 예측 진행 중... ---
#
# 성공적으로 예측이 완료되었습니다. 결과는 'test_predictions_by_date.csv' 파일에 저장되었습니다.

# %% [markdown]
# holt-winters 모델 (화담숲카페)

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. 데이터 불러오기
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/화담숲카페_data.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/화담숲카페_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 2. 고유한 메뉴 목록 추출
unique_menus = test_df['menu'].unique()
print(f"\n총 {len(unique_menus)}개의 메뉴에 대해 예측을 시작합니다.")

# 3. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 시작 ---")

    # 해당 메뉴에 대한 훈련/테스트 데이터 필터링
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    test_menu_df = test_df[test_df['menu'] == menu_item].copy()

    # 결측값 포함 행 제거 (날짜 생성 전)
    train_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)
    test_menu_df.dropna(subset=['year', 'month', 'day', 'sum'], inplace=True)

    # 날짜별 'sum' 값 합산 (중복 날짜 제거)
    train_agg = train_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()
    test_agg = test_menu_df.groupby(['year', 'month', 'day'])['sum'].sum().reset_index()

    if train_agg.empty or test_agg.empty:
        print(f"'{menu_item}' 메뉴의 데이터가 부족하여 예측을 건너뜁니다.")
        continue

    # 날짜 인덱스 생성
    train_agg['date'] = pd.to_datetime(train_agg[['year', 'month', 'day']])
    train_agg.set_index('date', inplace=True)

    test_agg['date'] = pd.to_datetime(test_agg[['year', 'month', 'day']])
    test_agg.set_index('date', inplace=True)

    # 시계열 데이터 선택
    train_series = train_agg['sum']
    test_series = test_agg['sum']

    # 날짜가 비어있는 경우 일별 빈도(D)로 채우기
    train_series = train_series.asfreq('D')
    test_series = test_series.asfreq('D')

    # Holt-Winters 모델 구현 및 훈련
    model = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_model = model.fit()

    # 예측
    forecast_steps = len(test_series)
    predictions = fitted_model.forecast(steps=forecast_steps)

    # 평가
    results_df = pd.DataFrame({
        'actual': test_series,
        'predicted': predictions
    }).dropna()

    if not results_df.empty:
        actual_values = results_df['actual']
        predictions_filtered = results_df['predicted']

        mse = mean_squared_error(actual_values, predictions_filtered)
        rmse = np.sqrt(mse)

        print(f"  예측값 (상위 5개): \n{predictions_filtered.head()}")
        print(f"\n  실제 테스트 데이터 (상위 5개): \n{actual_values.head()}")
        print(f"\n  MSE (Mean Squared Error): {mse:.2f}")
        print(f"  RMSE (Root Mean Squared Error): {rmse:.2f}")
    else:
        print("  예측과 실제값을 비교할 데이터가 부족하여 평가를 건너뜁니다.")

    print(f"\n--- 메뉴: '{menu_item}' 예측 종료 ---\n")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 5개의 메뉴에 대해 예측을 시작합니다.
#
# --- 메뉴: '메밀미숫가루' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    64.941606
# 2024-06-17     5.277200
# 2024-06-18    40.842841
# 2024-06-19    38.373820
# 2024-06-20    54.655637
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    92.0
# 2024-06-17     0.0
# 2024-06-18    40.0
# 2024-06-19    41.0
# 2024-06-20    40.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3035.48
#   RMSE (Root Mean Squared Error): 55.10
#
# --- 메뉴: '메밀미숫가루' 예측 종료 ---
#
#
# --- 메뉴: '아메리카노 HOT' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    11.016414
# 2024-06-17    -0.905652
# 2024-06-18    12.057338
# 2024-06-19    10.923838
# 2024-06-20    10.579959
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    12.0
# 2024-06-17     0.0
# 2024-06-18     6.0
# 2024-06-19     4.0
# 2024-06-20     5.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 2167.42
#   RMSE (Root Mean Squared Error): 46.56
#
# --- 메뉴: '아메리카노 HOT' 예측 종료 ---
#
#
# --- 메뉴: '아메리카노 ICE' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    81.752574
# 2024-06-17    -5.004566
# 2024-06-18    70.018505
# 2024-06-19    53.555930
# 2024-06-20    86.029546
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    87.0
# 2024-06-17     0.0
# 2024-06-18    60.0
# 2024-06-19    59.0
# 2024-06-20    76.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 6238.41
#   RMSE (Root Mean Squared Error): 78.98
#
# --- 메뉴: '아메리카노 ICE' 예측 종료 ---
#
#
# --- 메뉴: '카페라떼 ICE' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    20.629490
# 2024-06-17    -2.405855
# 2024-06-18    17.403292
# 2024-06-19    11.549964
# 2024-06-20    20.959481
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    25.0
# 2024-06-17     0.0
# 2024-06-18    12.0
# 2024-06-19    17.0
# 2024-06-20    20.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 406.00
#   RMSE (Root Mean Squared Error): 20.15
#
# --- 메뉴: '카페라떼 ICE' 예측 종료 ---
#
#
# --- 메뉴: '현미뻥스크림' 예측 시작 ---
#   예측값 (상위 5개):
# 2024-06-16    42.537976
# 2024-06-17    16.890218
# 2024-06-18    21.406382
# 2024-06-19    19.132242
# 2024-06-20    24.466257
# Name: predicted, dtype: float64
#
#   실제 테스트 데이터 (상위 5개):
# 2024-06-16    60.0
# 2024-06-17     0.0
# 2024-06-18     8.0
# 2024-06-19    28.0
# 2024-06-20    21.0
# Name: actual, dtype: float64
#
#   MSE (Mean Squared Error): 3422.02
#   RMSE (Root Mean Squared Error): 58.50
#
# --- 메뉴: '현미뻥스크림' 예측 종료 ---

# %% [markdown]
# 화담숲카페 영업장의 submission 파일 생성

# %%
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np
import warnings
from datetime import timedelta

# statsmodels 경고 무시
warnings.filterwarnings("ignore")

# 1. 데이터 불러오기 및 전처리
try:
    train_df = pd.read_csv('/content/drive/MyDrive/hackathon_data/train/화담숲카페_data.csv')
    test_df_original = pd.read_csv('/content/drive/MyDrive/hackathon_data/test/화담숲카페_data.csv')
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 날짜/시간 인덱스 생성
train_df['date'] = pd.to_datetime(train_df[['year', 'month', 'day']])
test_df_original['date'] = pd.to_datetime(test_df_original[['year', 'month', 'day']])

# 결측값 포함 행 제거
train_df.dropna(subset=['date', 'sum'], inplace=True)
test_df_original.dropna(subset=['date', 'sum'], inplace=True)

# 2. 예측 대상 날짜들 찾기 (모든 메뉴에 대해 공통)
# 테스트 데이터의 전체 날짜 범위
full_test_date_range = pd.date_range(
    start=test_df_original['date'].min(),
    end=test_df_original['date'].max(),
    freq='D'
)

# 테스트 데이터에 실제 값이 존재하는 날짜
dates_with_data = pd.to_datetime(test_df_original['date'].unique())

# 전체 날짜 범위에서 실제 데이터가 있는 날짜를 제외하여 빈 기간 식별
missing_dates = full_test_date_range.difference(dates_with_data)

# 마지막 7일 기간 추가 (테스트 데이터 마지막 날 다음 날부터)
last_test_date = test_df_original['date'].max()
final_week_dates = pd.date_range(
    start=last_test_date + timedelta(days=1),
    periods=7,
    freq='D'
)

# 예측할 날짜 전체 리스트 생성
forecast_dates = missing_dates.append(final_week_dates).sort_values()

# 예측할 날짜 목록 출력
print(f"\n총 {len(forecast_dates)}개의 날짜에 대해 예측을 수행합니다.")
print("예측 날짜 목록:")
print(forecast_dates)

# 3. 고유한 메뉴 목록 추출 및 예측
unique_menus = test_df_original['menu'].unique()
predictions_dict = {}

# 4. 메뉴별로 반복하여 예측 수행
for menu_item in unique_menus:
    print(f"\n--- 메뉴: '{menu_item}' 예측 진행 중... ---")

    # 해당 메뉴에 대한 훈련 데이터 필터링 및 합산
    train_menu_df = train_df[train_df['menu'] == menu_item].copy()
    train_series = train_menu_df.groupby('date')['sum'].sum().asfreq('D')

    if train_series.empty:
        predictions_dict[menu_item] = np.zeros(len(forecast_dates))
        print(f"  데이터 부족으로 '{menu_item}' 예측값을 0으로 처리합니다.")
        continue

    # Holt-Winters 모델 훈련
    model_hw = ExponentialSmoothing(
        train_series,
        trend='add',
        seasonal='add',
        seasonal_periods=7
    )
    fitted_hw = model_hw.fit()

    # 예측 수행
    menu_predictions_series = fitted_hw.predict(
        start=forecast_dates.min(),
        end=forecast_dates.max()
    )

    # 예측값을 빈 날짜에 맞게 필터링
    final_predictions_for_menu = menu_predictions_series.reindex(forecast_dates)

    # 예측값 저장
    predictions_dict[menu_item] = final_predictions_for_menu.values

# 5. 예측값으로 최종 데이터프레임 생성
final_predictions_df = pd.DataFrame(predictions_dict, index=forecast_dates)

# 열 라벨(column labels) 생성
column_labels = [f"화담숲카페_{menu}" for menu in unique_menus]
final_predictions_df.columns = column_labels

# 6. 예측 파일로 저장
file_name = 'test_predictions_by_date.csv'
final_predictions_df.to_csv(file_name, encoding='utf-8-sig', index=True)

print(f"\n성공적으로 예측이 완료되었습니다. 결과는 '{file_name}' 파일에 저장되었습니다.")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# 총 70개의 날짜에 대해 예측을 수행합니다.
# 예측 날짜 목록:
# DatetimeIndex(['2024-07-14', '2024-07-15', '2024-07-16', '2024-07-17',
#                '2024-07-18', '2024-07-19', '2024-07-20', '2024-08-18',
#                '2024-08-19', '2024-08-20', '2024-08-21', '2024-08-22',
#                '2024-08-23', '2024-08-24', '2024-09-22', '2024-09-23',
#                '2024-09-24', '2024-09-25', '2024-09-26', '2024-09-27',
#                '2024-09-28', '2024-10-27', '2024-10-28', '2024-10-29',
#                '2024-10-30', '2024-10-31', '2024-11-01', '2024-11-02',
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2025-01-05',
#                '2025-01-06', '2025-01-07', '2025-01-08', '2025-01-09',
#                '2025-01-10', '2025-01-11', '2025-02-09', '2025-02-10',
#                '2025-02-11', '2025-02-12', '2025-02-13', '2025-02-14',
#                '2025-02-15', '2025-03-16', '2025-03-17', '2025-03-18',
#                '2025-03-19', '2025-03-20', '2025-03-21', '2025-03-22',
#                '2025-04-20', '2025-04-21', '2025-04-22', '2025-04-23',
#                '2025-04-24', '2025-04-25', '2025-04-26', '2025-05-25',
#                '2025-05-26', '2025-05-27', '2025-05-28', '2025-05-29',
#                '2025-05-30', '2025-05-31'],
#               dtype='datetime64[ns]', freq=None)
#
# --- 메뉴: '메밀미숫가루' 예측 진행 중... ---
#
# --- 메뉴: '아메리카노 HOT' 예측 진행 중... ---
#
# --- 메뉴: '아메리카노 ICE' 예측 진행 중... ---
#
# --- 메뉴: '카페라떼 ICE' 예측 진행 중... ---
#
# --- 메뉴: '현미뻥스크림' 예측 진행 중... ---
#
# 성공적으로 예측이 완료되었습니다. 결과는 'test_predictions_by_date.csv' 파일에 저장되었습니다.

# %% [markdown]
# submission 파일들 경로 지정

# %%
import os
import shutil
from google.colab import drive

# 1. 구글 드라이브 마운트
print("구글 드라이브를 마운트합니다...")
drive.mount('/content/drive')

# 2. 이동할 파일 목록 지정
# 옮기고자 하는 파일 이름을 아래 리스트에 추가해주세요.
files_to_move = [
    'test_predictions_느티나무.csv',
    'test_predictions_담하.csv',
    'test_predictions_라그로타.csv',
    'test_predictions_미라시아.csv',
    'test_predictions_연회장.csv',
    'test_predictions_카페테리아.csv',
    'test_predictions_포레스트릿.csv',
    'test_predictions_화담숲주막.csv',
    'test_predictions_화담숲카페.csv'
]

# 3. 파일들을 옮길 목표 경로 지정
destination_dir = '/content/drive/MyDrive/hackathon_data/submission'

# 4. 목표 폴더가 없으면 생성
if not os.path.exists(destination_dir):
    print(f"'{destination_dir}' 폴더를 생성합니다.")
    os.makedirs(destination_dir)

# 5. 각 파일을 목표 폴더로 이동
for file_name in files_to_move:
    source_path = os.path.join(os.getcwd(), file_name)
    destination_path = os.path.join(destination_dir, file_name)

    try:
        shutil.move(source_path, destination_path)
        print(f"'{file_name}' -> '{destination_dir}' 로 이동 완료.")
    except FileNotFoundError:
        print(f"오류: '{file_name}' 파일을 찾을 수 없습니다. 현재 폴더에 파일이 있는지 확인해 주세요.")

print("\n모든 파일 이동 작업이 완료되었습니다.")
# Out:
# 구글 드라이브를 마운트합니다...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/MyDrive/hackathon_data/submission' 폴더를 생성합니다.
# 'test_predictions_느티나무.csv' -> '/content/drive/MyDrive/hackathon_data/submission' 로 이동 완료.
# 'test_predictions_담하.csv' -> '/content/drive/MyDrive/hackathon_data/submission' 로 이동 완료.
# 'test_predictions_라그로타.csv' -> '/content/drive/MyDrive/hackathon_data/submission' 로 이동 완료.
# 'test_predictions_미라시아.csv' -> '/content/drive/MyDrive/hackathon_data/submission' 로 이동 완료.
# 'test_predictions_연회장.csv' -> '/content/drive/MyDrive/hackathon_data/submission' 로 이동 완료.
# 'test_predictions_카페테리아.csv' -> '/content/drive/MyDrive/hackathon_data/submission' 로 이동 완료.
# 'test_predictions_포레스트릿.csv' -> '/content/drive/MyDrive/hackathon_data/submission' 로 이동 완료.
# 'test_predictions_화담숲주막.csv' -> '/content/drive/MyDrive/hackathon_data/submission' 로 이동 완료.
# 'test_predictions_화담숲카페.csv' -> '/content/drive/MyDrive/hackathon_data/submission' 로 이동 완료.
#
# 모든 파일 이동 작업이 완료되었습니다.

# %%
import pandas as pd
import os

# 합칠 파일 목록 (요청하신 순서대로)
file_list = [
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_느티나무.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_담하.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_라그로타.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_미라시아.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_연회장.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_카페테리아.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_포레스트릿.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_화담숲주막.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_화담숲카페.csv'
]

# 합쳐진 결과를 저장할 빈 데이터프레임 초기화
combined_df = None

# 파일들을 하나씩 불러와서 합치기
for file in file_list:
    try:
        # 첫 번째 열을 인덱스로 지정하여 불러옴
        df = pd.read_csv(file, index_col=0)

        if combined_df is None:
            # 첫 번째 파일로 데이터프레임 초기화
            combined_df = df
        else:
            # 다음 파일들을 기존 데이터프레임에 열 단위로 합치기
            combined_df = pd.concat([combined_df, df], axis=1)

        print(f"'{file}' 파일을 성공적으로 합쳤습니다.")

    except FileNotFoundError:
        print(f"오류: '{file}' 파일을 찾을 수 없습니다. 건너뜁니다.")
    except Exception as e:
        print(f"'{file}' 파일 처리 중 오류 발생: {e}")

if combined_df is not None:
    # 최종 결과 확인
    print("\n--- 합쳐진 최종 데이터프레임 정보 ---")
    combined_df.info()
    print("\n--- 합쳐진 최종 데이터프레임 상위 5개 행 ---")
    print(combined_df.head())

    # 파일을 CSV로 저장
    combined_df.to_csv('ordered_combined_predictions.csv', encoding='utf-8-sig', index=True)
    print("\n'ordered_combined_predictions.csv' 파일이 성공적으로 생성되었습니다.")
else:
    print("\n합칠 수 있는 파일이 없어 최종 데이터프레임이 생성되지 않았습니다.")
# Out:
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_느티나무.csv' 파일을 성공적으로 합쳤습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_담하.csv' 파일을 성공적으로 합쳤습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_라그로타.csv' 파일을 성공적으로 합쳤습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_미라시아.csv' 파일을 성공적으로 합쳤습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_연회장.csv' 파일을 성공적으로 합쳤습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_카페테리아.csv' 파일을 성공적으로 합쳤습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_포레스트릿.csv' 파일을 성공적으로 합쳤습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_화담숲주막.csv' 파일을 성공적으로 합쳤습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_화담숲카페.csv' 파일을 성공적으로 합쳤습니다.
#
# --- 합쳐진 최종 데이터프레임 정보 ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 2024-07-14 to 2025-05-31
# Columns: 193 entries, 느티나무_셀프BBQ_1인 수저세트 to 화담숲카페_현미뻥스크림
# dtypes: float64(193)
# memory usage: 106.1+ KB
#
# --- 합쳐진 최종 데이터프레임 상위 5개 행 ---
#             느티나무_셀프BBQ_1인 수저세트  느티나무_셀프BBQ_BBQ55(단체)  느티나무_셀프BBQ_대여료 30,000원  \
# 2024-07-14            5.258979             38.640063                3.532704
# 2024-07-15            2.061516             61.228322               -1.129349
# 2024-07-16            2.128147             57.837314                0.376052
# 2024-07-17            2.259300             70.574964                0.609066
# 2024-07-18            3.642000            109.379859                3.840234
#
#             느티나무_셀프BBQ_대여료 60,000원  느티나무_셀프BBQ_대여료 90,000원  \
# 2024-07-14                1.015318                0.444959
# 2024-07-15               -1.320921                0.039377
# 2024-07-16               -1.000985                0.067435
# 2024-07-17                0.138545                0.176945
# 2024-07-18                0.207102                0.247657
#
#             느티나무_셀프BBQ_본삼겹 (단품,실내)  느티나무_셀프BBQ_스프라이트 (단체)  느티나무_셀프BBQ_신라면  \
# 2024-07-14                1.453266               2.509902        4.327255
# 2024-07-15                0.875018              10.286252        2.249845
# 2024-07-16                1.059617               6.115168        4.551403
# 2024-07-17                1.165290              11.404654        2.903194
# 2024-07-18                1.284123              25.391488        5.443813
#
#             느티나무_셀프BBQ_쌈야채세트  느티나무_셀프BBQ_쌈장  ...  화담숲주막_스프라이트  화담숲주막_참살이 막걸리  \
# 2024-07-14          4.464978       1.117482  ...    24.662584      47.862700
# 2024-07-15          2.125899       0.264080  ...     8.660539      -8.861946
# 2024-07-16          3.113705       0.338803  ...    13.557819      18.726044
# 2024-07-17          3.854423       0.595111  ...    12.414558      23.762765
# 2024-07-18          5.692397       0.369658  ...    12.861935      36.182038
#
#             화담숲주막_찹쌀식혜   화담숲주막_콜라  화담숲주막_해물파전  화담숲카페_메밀미숫가루  화담숲카페_아메리카노 HOT  \
# 2024-07-14   46.420273  21.447361  145.964835     67.385408        11.458152
# 2024-07-15  -13.759358  -2.323355  -41.780079      7.721002        -0.463913
# 2024-07-16    7.702804   5.757367   30.055153     43.286643        12.499077
# 2024-07-17   13.773869   2.222628   48.861424     40.817623        11.365576
# 2024-07-18   22.911114   4.724768   92.347854     57.099439        11.021698
#
#             화담숲카페_아메리카노 ICE  화담숲카페_카페라떼 ICE  화담숲카페_현미뻥스크림
# 2024-07-14        85.267286       21.533066     44.012328
# 2024-07-15        -1.489854       -1.502278     18.364571
# 2024-07-16        73.533216       18.306868     22.880734
# 2024-07-17        57.070642       12.453540     20.606595
# 2024-07-18        89.544257       21.863057     25.940610
#
# [5 rows x 193 columns]
#
# 'ordered_combined_predictions.csv' 파일이 성공적으로 생성되었습니다.

# %%
import pandas as pd
import os

# 합칠 파일 목록을 요청하신 순서대로 나열합니다.
file_order = [
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_느티나무.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_담하.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_라그로타.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_미라시아.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_연회장.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_카페테리아.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_포레스트릿.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_화담숲주막.csv',
    '/content/drive/MyDrive/hackathon_data/submission/test_predictions_화담숲카페.csv'
]

# 합칠 데이터프레임을 담을 리스트
dfs_to_combine = []

# 파일들을 순서대로 불러와서 리스트에 추가합니다.
for file in file_order:
    try:
        df = pd.read_csv(file, index_col=0)
        dfs_to_combine.append(df)
        print(f"'{file}' 파일을 성공적으로 불러왔습니다.")
    except FileNotFoundError:
        print(f"오류: '{file}' 파일을 찾을 수 없습니다. 건너뜁니다.")
    except Exception as e:
        print(f"'{file}' 파일 처리 중 오류 발생: {e}")

if not dfs_to_combine:
    print("\n합칠 수 있는 파일이 없어 최종 데이터프레임이 생성되지 않았습니다.")
else:
    # 리스트에 담긴 데이터프레임들을 열(columns) 방향으로 합칩니다.
    # 순서가 보장됩니다.
    combined_df = pd.concat(dfs_to_combine, axis=1)

    # 최종 결과 확인
    print("\n--- 합쳐진 최종 데이터프레임 정보 ---")
    combined_df.info()
    print("\n--- 합쳐진 최종 데이터프레임 상위 5개 행 ---")
    print(combined_df.head())

    # 합쳐진 파일을 CSV로 저장
    output_filename = 'ordered_combined_predictions.csv'
    combined_df.to_csv(output_filename, encoding='utf-8-sig', index=True)
    print(f"\n'{output_filename}' 파일이 성공적으로 생성되었습니다.")
# Out:
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_느티나무.csv' 파일을 성공적으로 불러왔습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_담하.csv' 파일을 성공적으로 불러왔습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_라그로타.csv' 파일을 성공적으로 불러왔습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_미라시아.csv' 파일을 성공적으로 불러왔습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_연회장.csv' 파일을 성공적으로 불러왔습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_카페테리아.csv' 파일을 성공적으로 불러왔습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_포레스트릿.csv' 파일을 성공적으로 불러왔습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_화담숲주막.csv' 파일을 성공적으로 불러왔습니다.
# '/content/drive/MyDrive/hackathon_data/submission/test_predictions_화담숲카페.csv' 파일을 성공적으로 불러왔습니다.
#
# --- 합쳐진 최종 데이터프레임 정보 ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 2024-07-14 to 2025-05-31
# Columns: 193 entries, 느티나무_셀프BBQ_1인 수저세트 to 화담숲카페_현미뻥스크림
# dtypes: float64(193)
# memory usage: 106.1+ KB
#
# --- 합쳐진 최종 데이터프레임 상위 5개 행 ---
#             느티나무_셀프BBQ_1인 수저세트  느티나무_셀프BBQ_BBQ55(단체)  느티나무_셀프BBQ_대여료 30,000원  \
# 2024-07-14            5.258979             38.640063                3.532704
# 2024-07-15            2.061516             61.228322               -1.129349
# 2024-07-16            2.128147             57.837314                0.376052
# 2024-07-17            2.259300             70.574964                0.609066
# 2024-07-18            3.642000            109.379859                3.840234
#
#             느티나무_셀프BBQ_대여료 60,000원  느티나무_셀프BBQ_대여료 90,000원  \
# 2024-07-14                1.015318                0.444959
# 2024-07-15               -1.320921                0.039377
# 2024-07-16               -1.000985                0.067435
# 2024-07-17                0.138545                0.176945
# 2024-07-18                0.207102                0.247657
#
#             느티나무_셀프BBQ_본삼겹 (단품,실내)  느티나무_셀프BBQ_스프라이트 (단체)  느티나무_셀프BBQ_신라면  \
# 2024-07-14                1.453266               2.509902        4.327255
# 2024-07-15                0.875018              10.286252        2.249845
# 2024-07-16                1.059617               6.115168        4.551403
# 2024-07-17                1.165290              11.404654        2.903194
# 2024-07-18                1.284123              25.391488        5.443813
#
#             느티나무_셀프BBQ_쌈야채세트  느티나무_셀프BBQ_쌈장  ...  화담숲주막_스프라이트  화담숲주막_참살이 막걸리  \
# 2024-07-14          4.464978       1.117482  ...    24.662584      47.862700
# 2024-07-15          2.125899       0.264080  ...     8.660539      -8.861946
# 2024-07-16          3.113705       0.338803  ...    13.557819      18.726044
# 2024-07-17          3.854423       0.595111  ...    12.414558      23.762765
# 2024-07-18          5.692397       0.369658  ...    12.861935      36.182038
#
#             화담숲주막_찹쌀식혜   화담숲주막_콜라  화담숲주막_해물파전  화담숲카페_메밀미숫가루  화담숲카페_아메리카노 HOT  \
# 2024-07-14   46.420273  21.447361  145.964835     67.385408        11.458152
# 2024-07-15  -13.759358  -2.323355  -41.780079      7.721002        -0.463913
# 2024-07-16    7.702804   5.757367   30.055153     43.286643        12.499077
# 2024-07-17   13.773869   2.222628   48.861424     40.817623        11.365576
# 2024-07-18   22.911114   4.724768   92.347854     57.099439        11.021698
#
#             화담숲카페_아메리카노 ICE  화담숲카페_카페라떼 ICE  화담숲카페_현미뻥스크림
# 2024-07-14        85.267286       21.533066     44.012328
# 2024-07-15        -1.489854       -1.502278     18.364571
# 2024-07-16        73.533216       18.306868     22.880734
# 2024-07-17        57.070642       12.453540     20.606595
# 2024-07-18        89.544257       21.863057     25.940610
#
# [5 rows x 193 columns]
#
# 'ordered_combined_predictions.csv' 파일이 성공적으로 생성되었습니다.

# %%
import pandas as pd

# 1. 파일 불러오기
try:
    df = pd.read_csv('ordered_combined_predictions.csv', index_col=0)
    print("파일을 성공적으로 불러왔습니다.")
except FileNotFoundError:
    print("오류: 'ordered_combined_predictions.csv' 파일을 찾을 수 없습니다. 파일 이름을 확인해 주세요.")
    exit()

# 2. 새로운 행 라벨 생성
# TEST_00+1일 부터 TEST_09+7일 까지 총 70개의 라벨 생성
row_labels = []
for i in range(10):
    for j in range(1, 8):
        row_labels.append(f"TEST_{i:02d}+{j}일")

# 기존 데이터프레임의 행 수와 생성된 라벨의 수가 같은지 확인
if len(df) != len(row_labels):
    print(f"오류: 데이터프레임의 행 수({len(df)})와 생성된 라벨 수({len(row_labels)})가 일치하지 않습니다.")
    exit()

# 3. 데이터프레임의 인덱스를 새로운 라벨로 변경하고 이름 지정
df.index = row_labels
df.index.name = '영업일자'

# 4. 최종 결과 확인
print("\n--- 최종 데이터프레임 정보 ---")
df.info()
print("\n--- 최종 데이터프레임 상위 5개 행 ---")
print(df.head())

# 5. 파일을 CSV로 저장
output_filename = 'final_submission.csv'
df.to_csv(output_filename, encoding='utf-8-sig', index=True)
print(f"\n'{output_filename}' 파일이 성공적으로 생성되었습니다.")
# Out:
# 파일을 성공적으로 불러왔습니다.
#
# --- 최종 데이터프레임 정보 ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, TEST_00+1일 to TEST_09+7일
# Columns: 193 entries, 느티나무_셀프BBQ_1인 수저세트 to 화담숲카페_현미뻥스크림
# dtypes: float64(193)
# memory usage: 106.1+ KB
#
# --- 최종 데이터프레임 상위 5개 행 ---
#             느티나무_셀프BBQ_1인 수저세트  느티나무_셀프BBQ_BBQ55(단체)  느티나무_셀프BBQ_대여료 30,000원  \
# 영업일자
# TEST_00+1일            5.258979             38.640063                3.532704
# TEST_00+2일            2.061516             61.228322               -1.129349
# TEST_00+3일            2.128147             57.837314                0.376052
# TEST_00+4일            2.259300             70.574964                0.609066
# TEST_00+5일            3.642000            109.379859                3.840234
#
#             느티나무_셀프BBQ_대여료 60,000원  느티나무_셀프BBQ_대여료 90,000원  \
# 영업일자
# TEST_00+1일                1.015318                0.444959
# TEST_00+2일               -1.320921                0.039377
# TEST_00+3일               -1.000985                0.067435
# TEST_00+4일                0.138545                0.176945
# TEST_00+5일                0.207102                0.247657
#
#             느티나무_셀프BBQ_본삼겹 (단품,실내)  느티나무_셀프BBQ_스프라이트 (단체)  느티나무_셀프BBQ_신라면  \
# 영업일자
# TEST_00+1일                1.453266               2.509902        4.327255
# TEST_00+2일                0.875018              10.286252        2.249845
# TEST_00+3일                1.059617               6.115168        4.551403
# TEST_00+4일                1.165290              11.404654        2.903194
# TEST_00+5일                1.284123              25.391488        5.443813
#
#             느티나무_셀프BBQ_쌈야채세트  느티나무_셀프BBQ_쌈장  ...  화담숲주막_스프라이트  화담숲주막_참살이 막걸리  \
# 영업일자                                         ...
# TEST_00+1일          4.464978       1.117482  ...    24.662584      47.862700
# TEST_00+2일          2.125899       0.264080  ...     8.660539      -8.861946
# TEST_00+3일          3.113705       0.338803  ...    13.557819      18.726044
# TEST_00+4일          3.854423       0.595111  ...    12.414558      23.762765
# TEST_00+5일          5.692397       0.369658  ...    12.861935      36.182038
#
#             화담숲주막_찹쌀식혜   화담숲주막_콜라  화담숲주막_해물파전  화담숲카페_메밀미숫가루  화담숲카페_아메리카노 HOT  \
# 영업일자
# TEST_00+1일   46.420273  21.447361  145.964835     67.385408        11.458152
# TEST_00+2일  -13.759358  -2.323355  -41.780079      7.721002        -0.463913
# TEST_00+3일    7.702804   5.757367   30.055153     43.286643        12.499077
# TEST_00+4일   13.773869   2.222628   48.861424     40.817623        11.365576
# TEST_00+5일   22.911114   4.724768   92.347854     57.099439        11.021698
#
#             화담숲카페_아메리카노 ICE  화담숲카페_카페라떼 ICE  화담숲카페_현미뻥스크림
# 영업일자
# TEST_00+1일        85.267286       21.533066     44.012328
# TEST_00+2일        -1.489854       -1.502278     18.364571
# TEST_00+3일        73.533216       18.306868     22.880734
# TEST_00+4일        57.070642       12.453540     20.606595
# TEST_00+5일        89.544257       21.863057     25.940610
#
# [5 rows x 193 columns]
#
# 'final_submission.csv' 파일이 성공적으로 생성되었습니다.
